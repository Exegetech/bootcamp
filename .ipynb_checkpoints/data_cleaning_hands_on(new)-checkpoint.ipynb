# %% [markdown]
# ## Data Cleaning with Pandas: Hands On

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Part 1: Basics of Pandas & Categorical Column Encoding

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# - Survived: 0 berarti 'tidak selamat', 1 berarti 'selamat'
# - Pclass: kelas tiket, 1 = kelas 1 (paling mewah), 2 = kelas 2, 3 = kelas 3 (paling rendah)
# - Sex: jenis kelamin
# - Age: usia
# - SibSp: berapa banyak sibling/spouses yang ikut serta di dalam Titanic
# - Parch: berapa banyak parents/children yang ikut serta di dalam Titanic
# - Fare: uang yang dibayarkan (biaya) untuk perjalanan
# - Class: sama dengan Pclass, tapi di'spell' dengan kata-kata
# - Deck: kabin kapal
# - Embarked: kota keberangkatan, C = Cherbourg, Q = Queenstown, S = Southampton

# %%
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic.tail(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked  class  who  \
# 889         1       1  male  26.0      0      0  30.00        C  First  man
# 890         0       3  male  32.0      0      0   7.75        Q  Third  man
#
#      adult_male deck embark_town alive  alone
# 889        True    C   Cherbourg   yes   True
# 890        True  NaN  Queenstown    no   True

# %% [markdown]
# Filtering based on conditions

# %%
# filter only the female members

# %%
titanic['sex'] == 'female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: sex, Length: 891, dtype: bool

# %%
titanic[ titanic['sex'] == 'female'   ]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
## Filtering the third class passengers

titanic[titanic['class'] == 'Third']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 5           0       3    male   NaN      0      0   8.4583        Q  Third
# 7           0       3    male   2.0      3      1  21.0750        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 882         0       3  female  22.0      0      0  10.5167        S  Third
# 884         0       3    male  25.0      0      0   7.0500        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
female_passengers = titanic[titanic['sex'] == 'female'].reset_index()

# %%
female_passengers
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        1         1       1  female  38.0      1      0  71.2833        C
# 1        2         1       3  female  26.0      0      0   7.9250        S
# 2        3         1       1  female  35.0      1      0  53.1000        S
# 3        8         1       3  female  27.0      0      2  11.1333        S
# 4        9         1       2  female  14.0      1      0  30.0708        C
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 309    880         1       2  female  25.0      0      1  26.0000        S
# 310    882         0       3  female  22.0      0      0  10.5167        S
# 311    885         0       3  female  39.0      0      5  29.1250        Q
# 312    887         1       1  female  19.0      0      0  30.0000        S
# 313    888         0       3  female   NaN      1      2  23.4500        S
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Filtering with more than 1 conditions

# %%
# filtering female members who survived and is alone

# %%
titanic['sex'] == 'female'
titanic['survived'] == 1
titanic['alone'] == True
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: alone, Length: 891, dtype: bool

# %%
titanic[ ( titanic['sex'] == 'female'  ) & ( titanic['survived'] == 1 ) & ( titanic['alone'] == True )    ]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# 22          1       3  female  15.0      0      0   8.0292        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 842         1       1  female  30.0      0      0  31.0000        C   First
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 865         1       2  female  42.0      0      0  13.0000        S  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
female_survive = titanic[(titanic['sex'] == 'female') & (titanic['survived'] == 1)].reset_index(drop = True)
female_survive
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           1       1  female  38.0      1      0  71.2833        C   First
# 1           1       3  female  26.0      0      0   7.9250        S   Third
# 2           1       1  female  35.0      1      0  53.1000        S   First
# 3           1       3  female  27.0      0      2  11.1333        S   Third
# 4           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 228         1       2  female  28.0      1      0  24.0000        C  Second
# 229         1       3  female  15.0      0      0   7.2250        C   Third
# 230         1       1  female  56.0      0      1  83.1583        C   First
# 231         1       2  female  25.0      0      1  26.0000        S  Second
# 232         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Adding new column

# %%
# suppose the new column is the sum of sibsp and parch
titanic['relatives'] = titanic['sibsp'] + titanic['parch']

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  relatives
# 0    man        True  NaN  Southampton    no  False          1
# 1  woman       False    C    Cherbourg   yes  False          1
# 2  woman       False  NaN  Southampton   yes   True          0
# 3  woman       False    C  Southampton   yes  False          1
# 4    man        True  NaN  Southampton    no   True          0

# %%
df = pd.DataFrame({
    'A':[1,3,5,7,9,11],
    'B':[2,4,6,8,10,12]
})

df
# Out:
#     A   B
# 0   1   2
# 1   3   4
# 2   5   6
# 3   7   8
# 4   9  10
# 5  11  12

# %%
df2 = pd.DataFrame({
    'C':[10,20,30,40,50,60],
    'D':['Apple', 'Samsung', 'Oppo', 'Xiaomi', 'Huawei', 'Realme']
})
df2
# Out:
#     C        D
# 0  10    Apple
# 1  20  Samsung
# 2  30     Oppo
# 3  40   Xiaomi
# 4  50   Huawei
# 5  60   Realme

# %%
# Filter tabel di df yang kolom 'A' nya lebih dari 5

# %%
df[df['A'] >= 5]
# Out:
#     A   B
# 2   5   6
# 3   7   8
# 4   9  10
# 5  11  12

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  relatives
# 886    man        True  NaN  Southampton    no   True          0
# 887  woman       False    B  Southampton   yes   True          0
# 888  woman       False  NaN  Southampton    no  False          3
# 889    man        True    C    Cherbourg   yes   True          0
# 890    man        True  NaN   Queenstown    no   True          0

# %% [markdown]
# Adding new row

# %%
new_passenger = {
    'survived':0,
    'pclass':3,
    'sex':'male',
    'age':33.0,
    'sibsp':0,
    'parch':0,
    'fare':1.250,
    'embarked':'S',
    'class':'Third',
    'who':'man',
    'adult_male':True,
    'deck':'C',
    'embark_town':'Southampton',
    'alive':'no',
    'alone':True,
    'relatives':0
}

titanic = titanic.append(new_passenger, ignore_index = True)

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 887         1       1  female  19.0      0      0  30.00        S  First
# 888         0       3  female   NaN      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
# 891         0       3    male  33.0      0      0   1.25        S  Third
#
#        who  adult_male deck  embark_town alive  alone  relatives
# 887  woman       False    B  Southampton   yes   True          0
# 888  woman       False  NaN  Southampton    no  False          3
# 889    man        True    C    Cherbourg   yes   True          0
# 890    man        True  NaN   Queenstown    no   True          0
# 891    man        True    C  Southampton    no   True          0

# %%
new_passenger_2 = {
    'survived':[0,1],
    'pclass':[3,2],
    'sex':['male','female'],
    'age':[33.0,25.0],
    'sibsp':[0,2],
    'parch':[0,1],
    'fare':[1.250, 4.4],
    'embarked':['S','S'],
    'class':['Third', 'Second'],
    'who':['man', 'woman'],
    'adult_male':[True, False],
    'deck':['C', 'Z'],
    'embark_town':['Southampton', 'Southampton'],
    'alive':['no', 'yes'],
    'alone':[True, False],
    'relatives':[0,3]
}

titanic = titanic.append(pd.DataFrame(new_passenger_2), ignore_index = True)

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
# 891         0       3    male  33.0      0      0   1.25        S   Third
# 892         0       3    male  33.0      0      0   1.25        S   Third
# 893         1       2  female  25.0      2      1   4.40        S  Second
#
#        who  adult_male deck  embark_town alive  alone  relatives
# 889    man        True    C    Cherbourg   yes   True          0
# 890    man        True  NaN   Queenstown    no   True          0
# 891    man        True    C  Southampton    no   True          0
# 892    man        True    C  Southampton    no   True          0
# 893  woman       False    Z  Southampton   yes  False          3

# %%
#Filtering (female or survived) and pclass = 2

titanic[((titanic['sex'] == 'female') | (titanic['survived'] == 1)) & (titanic['pclass'] == 2)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 17          1       2    male   NaN      0      0  13.0000        S  Second
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# 41          0       2  female  27.0      1      0  21.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 865         1       2  female  42.0      0      0  13.0000        S  Second
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 893         1       2  female  25.0      2      1   4.4000        S  Second
#
# ...

# %% [markdown]
# One-Hot Encoding on the 'embarked' column:

# %%
titanic['embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 889    C
# 890    Q
# 891    S
# 892    S
# 893    S
# Name: embarked, Length: 894, dtype: object

# %%
# one-hot encoding on embarked and sex column
pd.get_dummies(titanic[['embarked', 'sex']])
# Out:
#      embarked_C  embarked_Q  embarked_S  sex_female  sex_male
# 0             0           0           1           0         1
# 1             1           0           0           1         0
# 2             0           0           1           1         0
# 3             0           0           1           1         0
# 4             0           0           1           0         1
# ..          ...         ...         ...         ...       ...
# 889           1           0           0           0         1
# 890           0           1           0           0         1
# 891           0           0           1           0         1
# 892           0           0           1           0         1
# 893           0           0           1           1         0
#
# [894 rows x 5 columns]

# %%
titanic = titanic.join(pd.get_dummies(titanic[['embarked', 'sex']]))

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
# 891         0       3    male  33.0      0      0   1.2500        S   Third
# 892         0       3    male  33.0      0      0   1.2500        S   Third
# 893         1       2  female  25.0      2      1   4.4000        S  Second
#
# ...

# %% [markdown]
# Rank Encoding on 'class' column

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
# 891         0       3    male  33.0      0      0   1.2500        S   Third
# 892         0       3    male  33.0      0      0   1.2500        S   Third
# 893         1       2  female  25.0      2      1   4.4000        S  Second
#
# ...

# %%
titanic['class'].unique()
# Out:
# array(['Third', 'First', 'Second'], dtype=object)

# %%
pemetaan_kelas = {
    'First':1,
    'Second':2,
    'Third':3,
}

# %%
titanic['class_after_map'] = titanic['class'].map(pemetaan_kelas)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
# 891         0       3    male  33.0      0      0   1.2500        S   Third
# 892         0       3    male  33.0      0      0   1.2500        S   Third
# 893         1       2  female  25.0      2      1   4.4000        S  Second
#
# ...

# %%
titanic.drop(['pclass','sex', 'embarked'], axis = 'columns', inplace = True)

# %%
titanic.drop(['age'], axis = 'columns', inplace = True)

# %%
titanic
# Out:
#      survived  sibsp  parch     fare   class    who  adult_male deck  \
# 0           0      1      0   7.2500   Third    man        True  NaN
# 1           1      1      0  71.2833   First  woman       False    C
# 2           1      0      0   7.9250   Third  woman       False  NaN
# 3           1      1      0  53.1000   First  woman       False    C
# 4           0      0      0   8.0500   Third    man        True  NaN
# ..        ...    ...    ...      ...     ...    ...         ...  ...
# 889         1      0      0  30.0000   First    man        True    C
# 890         0      0      0   7.7500   Third    man        True  NaN
# 891         0      0      0   1.2500   Third    man        True    C
# 892         0      0      0   1.2500   Third    man        True    C
# 893         1      2      1   4.4000  Second  woman       False    Z
#
#      embark_town alive  alone  relatives  embarked_C  embarked_Q  embarked_S  \
# ...

# %% [markdown]
# ### Part 2: Missing Value

# %%
titanic = pd.read_csv('titanic_passenger.csv')

# %%
titanic
# Out:
#      Survived     Sex   Age  SiblingsSpouse  ParentChildren     Fare  \
# 0           0    male  22.0               1               0   7.2500
# 1           1  female  38.0               1               0  71.2833
# 2           1  female  26.0               0               0   7.9250
# 3           1  female  35.0               1               0  53.1000
# 4           0    male  35.0               0               0   8.0500
# ..        ...     ...   ...             ...             ...      ...
# 886         0    male  27.0               0               0  13.0000
# 887         1  female  19.0               0               0  30.0000
# 888         0  female   NaN               1               2  23.4500
# 889         1    male  26.0               0               0  30.0000
# 890         0    male  32.0               0               0   7.7500
#
#     EmbarkedCity   Class Deck
# 0              S   Third  NaN
# 1              C   First    C
# 2              S   Third  NaN
# ...

# %% [markdown]
# - Survived: 0 berarti 'tidak selamat', 1 berarti 'selamat'
# - Pclass: kelas tiket, 1 = kelas 1 (paling mewah), 2 = kelas 2, 3 = kelas 3 (paling rendah)
# - Sex: jenis kelamin
# - Age: usia
# - SibSp: berapa banyak sibling/spouses yang ikut serta di dalam Titanic
# - Parch: berapa banyak parents/children yang ikut serta di dalam Titanic
# - Fare: uang yang dibayarkan (biaya) untuk perjalanan
# - Class: sama dengan Pclass, tapi di'spell' dengan kata-kata
# - Deck: kabin kapal
# - Embarked: kota keberangkatan, C = Cherbourg, Q = Queenstown, S = Southampton

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        891 non-null    int64
#  1   Sex             891 non-null    object
#  2   Age             714 non-null    float64
#  3   SiblingsSpouse  891 non-null    int64
#  4   ParentChildren  891 non-null    int64
#  5   Fare            891 non-null    float64
#  6   EmbarkedCity    889 non-null    object
#  7   Class           891 non-null    object
#  8   Deck            203 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 62.8+ KB

# %%
700/891
# Out:
# 0.7856341189674523

# %%
titanic
# Out:
#      Survived     Sex   Age  SiblingsSpouse  ParentChildren     Fare  \
# 0           0    male  22.0               1               0   7.2500
# 1           1  female  38.0               1               0  71.2833
# 2           1  female  26.0               0               0   7.9250
# 3           1  female  35.0               1               0  53.1000
# 4           0    male  35.0               0               0   8.0500
# ..        ...     ...   ...             ...             ...      ...
# 886         0    male  27.0               0               0  13.0000
# 887         1  female  19.0               0               0  30.0000
# 888         0  female   NaN               1               2  23.4500
# 889         1    male  26.0               0               0  30.0000
# 890         0    male  32.0               0               0   7.7500
#
#     EmbarkedCity   Class Deck
# 0              S   Third  NaN
# 1              C   First    C
# 2              S   Third  NaN
# ...

# %% [markdown]
# #### Method 1: Drop the Column
#
# Jika kolom tersebut memiliki banyak missing values (lebih dari 50-60%), maka sulit rasanya bisa mendapatkan metode imputasi yang akurat. Apalagi, jika kolom tersebut dirasa memiliki informasi yang minim.
#
# Jika hal ini terjadi, maka hal yang dapat dilakukan adalah menghilangkan seluruh kolom (tidak menggunakan kolom tersebut dalam EDA / Modelling). Hal ini yang akan kita lakukan kepada kolom `Deck`.

# %%
titanic.drop('Deck', axis = 'columns', inplace = True)

# %%
titanic.columns
# Out:
# Index(['Survived', 'Sex', 'Age', 'SiblingsSpouse', 'ParentChildren', 'Fare',
#        'EmbarkedCity', 'Class'],
#       dtype='object')

# %% [markdown]
# Kolom `Deck` sudah tidak ada di dataframe kita^.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        891 non-null    int64
#  1   Sex             891 non-null    object
#  2   Age             714 non-null    float64
#  3   SiblingsSpouse  891 non-null    int64
#  4   ParentChildren  891 non-null    int64
#  5   Fare            891 non-null    float64
#  6   EmbarkedCity    889 non-null    object
#  7   Class           891 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 55.8+ KB

# %%
2/891
# Out:
# 0.002244668911335578

# %% [markdown]
# #### Method 2: Remove the Rows

# %% [markdown]
# Apabila missing values kurang dari 50%, maka hal yang dapat dilakukan adalah menghilangkan semua baris dengan missing values. Ini adalah metode yang paling 'mudah', namun memiliki beberapa konsekuensi:
# - Kehilangan informasi dari kolom lain yang penting (dalam kebanyakan kasus, baris yang dihilangkan itu sebenarnya tidak bermasalah di kolom-kolom lain)
# - Dataset size menjadi sedikit, bila yang dihilangkan cukup banyak

# %%
### Mau menghilangkan yang NULL untuk kolom Embarked aja
### KEEP the Missing Value in kolom Age

# %%
titanic
# Out:
#      Survived     Sex   Age  SiblingsSpouse  ParentChildren     Fare  \
# 0           0    male  22.0               1               0   7.2500
# 1           1  female  38.0               1               0  71.2833
# 2           1  female  26.0               0               0   7.9250
# 3           1  female  35.0               1               0  53.1000
# 4           0    male  35.0               0               0   8.0500
# ..        ...     ...   ...             ...             ...      ...
# 886         0    male  27.0               0               0  13.0000
# 887         1  female  19.0               0               0  30.0000
# 888         0  female   NaN               1               2  23.4500
# 889         1    male  26.0               0               0  30.0000
# 890         0    male  32.0               0               0   7.7500
#
#     EmbarkedCity   Class
# 0              S   Third
# 1              C   First
# 2              S   Third
# 3              S   First
# ...

# %%
df_update = titanic.copy()
df_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        891 non-null    int64
#  1   Sex             891 non-null    object
#  2   Age             714 non-null    float64
#  3   SiblingsSpouse  891 non-null    int64
#  4   ParentChildren  891 non-null    int64
#  5   Fare            891 non-null    float64
#  6   EmbarkedCity    889 non-null    object
#  7   Class           891 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 55.8+ KB

# %%
df_update[df_update['EmbarkedCity'].isnull()]
# Out:
#      Survived     Sex   Age  SiblingsSpouse  ParentChildren  Fare  \
# 61          1  female  38.0               0               0  80.0
# 829         1  female  62.0               0               0  80.0
#
#     EmbarkedCity  Class
# 61           NaN  First
# 829          NaN  First

# %%
df_update[~df_update['EmbarkedCity'].isnull()]
# Out:
#      Survived     Sex   Age  SiblingsSpouse  ParentChildren     Fare  \
# 0           0    male  22.0               1               0   7.2500
# 1           1  female  38.0               1               0  71.2833
# 2           1  female  26.0               0               0   7.9250
# 3           1  female  35.0               1               0  53.1000
# 4           0    male  35.0               0               0   8.0500
# ..        ...     ...   ...             ...             ...      ...
# 886         0    male  27.0               0               0  13.0000
# 887         1  female  19.0               0               0  30.0000
# 888         0  female   NaN               1               2  23.4500
# 889         1    male  26.0               0               0  30.0000
# 890         0    male  32.0               0               0   7.7500
#
#     EmbarkedCity   Class
# 0              S   Third
# 1              C   First
# 2              S   Third
# 3              S   First
# ...

# %%
### memilih baris yang tidak kosong
df_update = df_update[~df_update['EmbarkedCity'].isnull()].reset_index(drop = True)

# %%
df_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        889 non-null    int64
#  1   Sex             889 non-null    object
#  2   Age             712 non-null    float64
#  3   SiblingsSpouse  889 non-null    int64
#  4   ParentChildren  889 non-null    int64
#  5   Fare            889 non-null    float64
#  6   EmbarkedCity    889 non-null    object
#  7   Class           889 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 55.7+ KB

# %% [markdown]
# Kolom Embarked sudah dihilangkan missing valuesnya. Sehingga tersisa 889 rows yang sudah tidak ada missing valuesnya lagi. Jadi, kolom yang sisa adalah 'Age'.

# %%
df_update[df_update['Age'].isnull()]
# Out:
#      Survived     Sex  Age  SiblingsSpouse  ParentChildren     Fare  \
# 5           0    male  NaN               0               0   8.4583
# 17          1    male  NaN               0               0  13.0000
# 19          1  female  NaN               0               0   7.2250
# 26          0    male  NaN               0               0   7.2250
# 28          1  female  NaN               0               0   7.8792
# ..        ...     ...  ...             ...             ...      ...
# 857         0    male  NaN               0               0   7.2292
# 861         0  female  NaN               8               2  69.5500
# 866         0    male  NaN               0               0   9.5000
# 876         0    male  NaN               0               0   7.8958
# 886         0  female  NaN               1               2  23.4500
#
#     EmbarkedCity   Class
# 5              Q   Third
# 17             S  Second
# 19             C   Third
# 26             C   Third
# ...

# %%
177/889
# Out:
# 0.19910011248593926

# %% [markdown]
# Berarti, terdapat sekitar 20% baris yang mengalami missing value di kolom `Age`.

# %%
df_update['Age'].median()
# Out:
# 28.0

# %% [markdown]
# Nah, sekarang, coba kita lihat dulu, median umur dari passenger di Titanic, berdasarkan tingkat keselamatan, jenis kelamin, dan kota keberangkatan

# %%
df_update.groupby(['Survived', 'Sex', 'EmbarkedCity'])['Age'].median()
# Out:
# Survived  Sex     EmbarkedCity
# 0         female  C               17.50
#                   Q               30.50
#                   S               25.00
#           male    C               30.00
#                   Q               31.00
#                   S               28.25
# 1         female  C               27.00
#                   Q               19.00
#                   S               29.00
#           male    C               26.50
#                   Q               29.00
#                   S               28.00
# Name: Age, dtype: float64

# %%
df_update.groupby(['Survived', 'Sex', 'EmbarkedCity'])['Age'].median().reset_index()
# Out:
#     Survived     Sex EmbarkedCity    Age
# 0          0  female            C  17.50
# 1          0  female            Q  30.50
# 2          0  female            S  25.00
# 3          0    male            C  30.00
# 4          0    male            Q  31.00
# 5          0    male            S  28.25
# 6          1  female            C  27.00
# 7          1  female            Q  19.00
# 8          1  female            S  29.00
# 9          1    male            C  26.50
# 10         1    male            Q  29.00
# 11         1    male            S  28.00

# %%
median_umur = df_update.groupby(['Survived', 'Sex', 'EmbarkedCity'])['Age'].median().reset_index()
median_umur
# Out:
#     Survived     Sex EmbarkedCity    Age
# 0          0  female            C  17.50
# 1          0  female            Q  30.50
# 2          0  female            S  25.00
# 3          0    male            C  30.00
# 4          0    male            Q  31.00
# 5          0    male            S  28.25
# 6          1  female            C  27.00
# 7          1  female            Q  19.00
# 8          1  female            S  29.00
# 9          1    male            C  26.50
# 10         1    male            Q  29.00
# 11         1    male            S  28.00

# %%
### Ganti Nama Kolom biar Tidak Rancu

median_umur['MedianAge'] = median_umur['Age']

# %%
median_umur
# Out:
#     Survived     Sex EmbarkedCity    Age  MedianAge
# 0          0  female            C  17.50      17.50
# 1          0  female            Q  30.50      30.50
# 2          0  female            S  25.00      25.00
# 3          0    male            C  30.00      30.00
# 4          0    male            Q  31.00      31.00
# 5          0    male            S  28.25      28.25
# 6          1  female            C  27.00      27.00
# 7          1  female            Q  19.00      19.00
# 8          1  female            S  29.00      29.00
# 9          1    male            C  26.50      26.50
# 10         1    male            Q  29.00      29.00
# 11         1    male            S  28.00      28.00

# %%
median_umur.drop(['Age'], axis = 'columns', inplace = True)

# %%
median_umur
# Out:
#     Survived     Sex EmbarkedCity  MedianAge
# 0          0  female            C      17.50
# 1          0  female            Q      30.50
# 2          0  female            S      25.00
# 3          0    male            C      30.00
# 4          0    male            Q      31.00
# 5          0    male            S      28.25
# 6          1  female            C      27.00
# 7          1  female            Q      19.00
# 8          1  female            S      29.00
# 9          1    male            C      26.50
# 10         1    male            Q      29.00
# 11         1    male            S      28.00

# %% [markdown]
# #### Method 3: Mengisi dengan Mean/Median

# %% [markdown]
# Mari kita isi missing values di kolom 'Age' berdasarkan median umur masing-masing kelompok.

# %%
df_update[df_update['Age'].isnull()].head(3)
# Out:
#     Survived     Sex  Age  SiblingsSpouse  ParentChildren     Fare  \
# 5          0    male  NaN               0               0   8.4583
# 17         1    male  NaN               0               0  13.0000
# 19         1  female  NaN               0               0   7.2250
#
#    EmbarkedCity   Class
# 5             Q   Third
# 17            S  Second
# 19            C   Third

# %% [markdown]
# Lihat 2 baris pertama.
#
# 1. Untuk index 5. Survived = 0. Sex = 1. Embarked = Q. Maka, berdasarkan tabel `median_umur`, kita mengetahui bahwa median umur passenger Titanic yang **tidak survived** dan **berjenis kelamin Pria** yang berasal dari **kota keberangkatan Q** adalah 31 tahun. Nah, untuk passenger index 5 ini, karena `Age` dia missing, kita akan isi dengan 31 tahun (karena itu estimasi kita untuk passenger-passenger yang mirip seperti dia).
#
#
# 2. Untuk index 17. Survived = 1. Sex = 1. Embarked = S. Check ke tabel `median_umur`. Untuk passenger Titanic lain yang **selamat**, **berjenis kelamin Pria**, dan berasal dari **kota keberangkatan S**, median umurnya adalah 28. Maka, kita akan isi `Age` untuk passenger di index 17 ini dengan 28 tahun.
#
#
# Kita lakukan ini untuk semua baris yang mengalami missing value di `Age`. Yaitu, lihat karakteristik pengunjung berdasarkan `Survived`, `Sex`, serta `Embarked`. Dan isilah missing value di `Age` dengan median umur passenger yang 'sejenis'.

# %%
median_umur
# Out:
#     Survived     Sex EmbarkedCity  MedianAge
# 0          0  female            C      17.50
# 1          0  female            Q      30.50
# 2          0  female            S      25.00
# 3          0    male            C      30.00
# 4          0    male            Q      31.00
# 5          0    male            S      28.25
# 6          1  female            C      27.00
# 7          1  female            Q      19.00
# 8          1  female            S      29.00
# 9          1    male            C      26.50
# 10         1    male            Q      29.00
# 11         1    male            S      28.00

# %% [markdown]
# Kita dapat melakukan hal ini dengan: MERGE!
#
#
# Kita akan merge `df_update` dengan `median_umur`.

# %%
df_update = df_update.merge(median_umur, how = 'left')

# %%
df_update.head(6)
# Out:
#    Survived     Sex   Age  SiblingsSpouse  ParentChildren     Fare  \
# 0         0    male  22.0               1               0   7.2500
# 1         1  female  38.0               1               0  71.2833
# 2         1  female  26.0               0               0   7.9250
# 3         1  female  35.0               1               0  53.1000
# 4         0    male  35.0               0               0   8.0500
# 5         0    male   NaN               0               0   8.4583
#
#   EmbarkedCity  Class  MedianAge
# 0            S  Third      28.25
# 1            C  First      27.00
# 2            S  Third      29.00
# 3            S  First      29.00
# 4            S  Third      28.25
# 5            Q  Third      31.00

# %% [markdown]
# Nice! Sudah ada kolom baru di `df_update`. Sekarang, yuk, check lagi baris-baris di `df_update` yang mengalami missing value di kolom `Age`.

# %%
df_update[df_update['Age'].isnull()].head(3)
# Out:
#     Survived     Sex  Age  SiblingsSpouse  ParentChildren     Fare  \
# 5          0    male  NaN               0               0   8.4583
# 17         1    male  NaN               0               0  13.0000
# 19         1  female  NaN               0               0   7.2250
#
#    EmbarkedCity   Class  MedianAge
# 5             Q   Third       31.0
# 17            S  Second       28.0
# 19            C   Third       27.0

# %% [markdown]
# Nah, berarti, untuk setiap nilai 'NaN' di kolom `Age`, ganti dengan nilai `MedianAge`. Itu yang akan kita lakukan!

# %%
df_update['Age'] = df_update['Age'].fillna(df_update['MedianAge'])

# %%
df_update.head(6)
# Out:
#    Survived     Sex   Age  SiblingsSpouse  ParentChildren     Fare  \
# 0         0    male  22.0               1               0   7.2500
# 1         1  female  38.0               1               0  71.2833
# 2         1  female  26.0               0               0   7.9250
# 3         1  female  35.0               1               0  53.1000
# 4         0    male  35.0               0               0   8.0500
# 5         0    male  31.0               0               0   8.4583
#
#   EmbarkedCity  Class  MedianAge
# 0            S  Third      28.25
# 1            C  First      27.00
# 2            S  Third      29.00
# 3            S  First      29.00
# 4            S  Third      28.25
# 5            Q  Third      31.00

# %%
df_update
# Out:
#      Survived     Sex   Age  SiblingsSpouse  ParentChildren     Fare  \
# 0           0    male  22.0               1               0   7.2500
# 1           1  female  38.0               1               0  71.2833
# 2           1  female  26.0               0               0   7.9250
# 3           1  female  35.0               1               0  53.1000
# 4           0    male  35.0               0               0   8.0500
# ..        ...     ...   ...             ...             ...      ...
# 884         0    male  27.0               0               0  13.0000
# 885         1  female  19.0               0               0  30.0000
# 886         0  female  25.0               1               2  23.4500
# 887         1    male  26.0               0               0  30.0000
# 888         0    male  32.0               0               0   7.7500
#
#     EmbarkedCity   Class  MedianAge
# 0              S   Third      28.25
# 1              C   First      27.00
# ...

# %%
df_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 888
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        889 non-null    int64
#  1   Sex             889 non-null    object
#  2   Age             889 non-null    float64
#  3   SiblingsSpouse  889 non-null    int64
#  4   ParentChildren  889 non-null    int64
#  5   Fare            889 non-null    float64
#  6   EmbarkedCity    889 non-null    object
#  7   Class           889 non-null    object
#  8   MedianAge       889 non-null    float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 69.5+ KB

# %% [markdown]
# Nice! Sudah tidak ada missing values di kolom `Age`.

# %%
sns.histplot(data = df_update, x = 'Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### Part 3: Outliers

# %% [markdown]
# Untuk membahas outlier, maka kita pakai data Boston Property Price.

# %%
boston_df = pd.read_csv('boston_df.csv')
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO  LSTAT  TARGET
# 0       15.3   4.98    24.0
# 1       17.8   9.14    21.6
# ...

# %% [markdown]
#  - CRIM:     per capita crime rate by town
#  - ZN:       proportion of residential land zoned for lots over 25,000 sq.ft.
#  - INDUS:    proportion of non-retail business acres per town
#  - CHAS:     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#  - NOX:      nitric oxides concentration (parts per 10 million)
#  - RM:       average number of rooms per dwelling
#  - AGE:      proportion of owner-occupied units built prior to 1940
#  - DIS:      weighted distances to five Boston employment centres
#  - RAD:      index of accessibility to radial highways
#  - TAX:      full-value property-tax rate per USD 10,000
#  - PTRATIO:  pupil-teacher ratio by town
#  - LSTAT:    % lower status of the population
#  - TARGET:     Median value of owner-occupied homes in USD 1000's

# %% [markdown]
# #### Univariate Outlier Analysis

# %% [markdown]
# Sekarang, mari kita gunakan boxplot untuk melihat kolom `DIS`, apakah terdapat outlier atau tidak

# %%
import seaborn as sns
sns.boxplot(x=boston_df['DIS'])
plt.show()

# %% [markdown]
# Berarti, terdapat beberapa outlier, yaitu yang `DIS` nya > 10.

# %% [markdown]
# Untuk univariate outlier analysis, kita mengukur:
# - Q1 dan Q3 dari kolom tersebut
# - IQR = Q3 - Q1 dari kolom tersebut
# - Apakah ada data yang < Q1 - 1.5 * IQR, atau data yang > Q3 + 1.5 * IQR? Jika ada, maka data tersebut merupakan Outlier.
#
# Untuk mencari baris mana saja yang outlier, kita bisa menggunakan bantuan fungsi di bawah ini:

# %%
def check_outlier(data, column):
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    return ['outlier' if (x<q1-1.5*iqr or x>q3+1.5*iqr) 
                                 else 'not-outlier' for x in data[column].values]

# %%
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO  LSTAT  TARGET
# 0       15.3   4.98    24.0
# 1       17.8   9.14    21.6
# ...

# %%
boston_df['outlier_DIS'] = check_outlier(data=boston_df, column='DIS')

# %%
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO  LSTAT  TARGET  outlier_DIS
# 0       15.3   4.98    24.0  not-outlier
# ...

# %%
boston_df[boston_df['outlier_DIS'] == 'outlier']
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE      DIS  RAD    TAX  \
# 351  0.07950  60.0   1.69   0.0  0.411  6.579  35.9  10.7103  4.0  411.0
# 352  0.07244  60.0   1.69   0.0  0.411  5.884  18.5  10.7103  4.0  411.0
# 353  0.01709  90.0   2.02   0.0  0.410  6.728  36.1  12.1265  5.0  187.0
# 354  0.04301  80.0   1.91   0.0  0.413  5.663  21.9  10.5857  4.0  334.0
# 355  0.10659  80.0   1.91   0.0  0.413  5.936  19.5  10.5857  4.0  334.0
#
#      PTRATIO  LSTAT  TARGET outlier_DIS
# 351     18.3   5.49    24.1     outlier
# 352     18.3   7.79    18.6     outlier
# 353     17.0   4.50    30.1     outlier
# 354     22.0   8.05    18.2     outlier
# 355     22.0   5.57    20.6     outlier

# %%
contoh = [1, 10, 100, 1000, 10000, 1000000]
np.log(contoh)
# Out:
# array([ 0.        ,  2.30258509,  4.60517019,  6.90775528,  9.21034037,
#        13.81551056])

# %%
boston_df['log_DIS'] = np.log(boston_df['DIS'])

# %%
sns.boxplot(x=boston_df['log_DIS'])
plt.show()
