# %% [markdown]
# ## Question 1

# %% [markdown]
# Create table bernama dim_customer_(nick name kamu) dengan column name (string) , birthdate (date) , and gender (string)

# %% [markdown]
# CREATE TABLE dim_customer_vertikal <br>
# (nama STRING , <br>
#  birthdate DATE, <br>
#  gender STRING);

# %% [markdown]
# INSERT INTO dim_customer_vertikal <Br>
# VALUES ('Puff','1998-05-15','Female'), <br>
# ('TuanKrab','1955-12-12','Male'), <Br>
# ('SpongeBob','1999-12-19','Male'), <br>
# ('Patricia','1995-11-19','Female'), <br>
# ('Farah','1993-11-19','Female'); <br>

# %% [markdown]
# Select * pada dim_customer_(nick name kamu)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Screen capture

# %% [markdown]
# ## Question 2

# %% [markdown]
# Alter tabel dim_customer_(nick name kamu) dan ubah namanya menjadi dim_customer_(nick name kamu)_(movie yang kamu suka)

# %% [markdown]
# ALTER TABLE dim_customer_vertikal RENAME TO dim_customer_vertikal_SpongebobSquarepant;

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create table bernama dim_customer_(last name kamu) dan isi datanya dengan data pada dim customer yang memiliki gender female

# %% [markdown]
# CREATE TABLE dim_customer_willis AS <br>
# SELECT * FROM dim_customer_vertikal_SpongebobSquarepant WHERE gender = 'Female';

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 4

# %% [markdown]
# Create sebuah table yang berasal dari google spreadsheet. Nama table, isi table, tujuan table dsb bebas sekreatif mungkin. Sertakan screenshot saat 'create table' , dan SELECT * FROM Table setelah table jadi

# %% [markdown]
# **Screenshot please put here**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
