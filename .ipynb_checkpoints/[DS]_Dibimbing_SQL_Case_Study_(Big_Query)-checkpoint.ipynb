# %% [markdown]
# * Made with <3 by Aisyah .
# * Please contact me if you want to re-share or modify this learning material for teaching or any publishing purpose.
# * Contact : [link text](https://id.linkedin.com/in/aisyahkhulf)

# %% [markdown]
# # MAGIC SQL

# %% [markdown]
# Import Package + Connect to database

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# %load_ext google.cloud.bigquery

# %% [markdown]
# Untuk melakukan query menggunakan magic SQL, yg dilakukan adalah dengan memulai setiap query dengan ***%%bigquery --project projectname***
#
# Contoh :
#
#
# * %%bigquery --project sonic-utility-323206
# * selanjutnya isi dengan SQL Query biasa

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT *
# FROM dibimbing-386613.dibimbing.dim_product
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      product_id           product_name            model_name  color  \
# 0           604     Road-750 Black, 44              Road-750  Black
# 1           605     Road-750 Black, 48              Road-750  Black
# 2           606     Road-750 Black, 52              Road-750  Black
# 3           584     Road-750 Black, 58              Road-750  Black
# 4           326       Road-650 Red, 44              Road-650    Red
# ..          ...                    ...                   ...    ...
# 392         540           HL Road Tire          HL Road Tire     NA
# 393         537       HL Mountain Tire      HL Mountain Tire     NA
# 394         477  Water Bottle - 30 oz.          Water Bottle     NA
# 395         479       Road Bottle Cage      Road Bottle Cage     NA
# 396         478   Mountain Bottle Cage  Mountain Bottle Cage     NA
#
#     size_range       cost  normal_price       sub_category     category
# 0     42-46 CM  4811094.4     7559860.0         Road Bikes        Bikes
# 1     48-52 CM  4811094.4     7559860.0         Road Bikes        Bikes
# 2     48-52 CM  4811094.4     7559860.0         Road Bikes        Bikes
# 3     54-58 CM  4811094.4     7559860.0         Road Bikes        Bikes
# 4     42-46 CM  5784048.2     9787374.8         Road Bikes        Bikes
# ..         ...        ...           ...                ...          ...
# 392         NA   170693.6      456400.0    Tires and Tubes  Accessories
# 393         NA   183260.0      490000.0    Tires and Tubes  Accessories
# 394         NA    26128.2       69860.0  Bottles and Cages  Accessories
# 395         NA    47072.2      125860.0  Bottles and Cages  Accessories
# 396         NA    52308.2      139860.0  Bottles and Cages  Accessories
#
# [397 rows x 9 columns]

# %% [markdown]
# Query dengan magic SQL sama persis dengan SQL query yang kita lakukan di Big Query Console  https://console.cloud.google.com/bigquery?pli=1

# %% [markdown]
# # Get To Know The Database

# %% [markdown]
# Hal pertama yg penting untuk dilakukan adalah mengetahui apa saja tabel yg sedang kita analysis. Beberapa hal yg perlu kita aware adalah :
# 1. Nama tabel
# 2. Hubungan tiap tabel (table relationship)

# %% [markdown]
# ![table relationship 2.PNG](data:image/png;base64,...)

# %% [markdown]
# Example 1
#
# **`Apa saja product2 yg dijual oleh BeeCycle?`**

# %% [markdown]
# *   tarik all column dari tabel dibimbing.dim_product ,

# %%
# %%bigquery --project sonic-utility-323206
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      product_id           product_name            model_name  color  \
# 0           604     Road-750 Black, 44              Road-750  Black
# 1           605     Road-750 Black, 48              Road-750  Black
# 2           606     Road-750 Black, 52              Road-750  Black
# 3           584     Road-750 Black, 58              Road-750  Black
# 4           326       Road-650 Red, 44              Road-650    Red
# ..          ...                    ...                   ...    ...
# 392         540           HL Road Tire          HL Road Tire     NA
# 393         537       HL Mountain Tire      HL Mountain Tire     NA
# 394         477  Water Bottle - 30 oz.          Water Bottle     NA
# 395         479       Road Bottle Cage      Road Bottle Cage     NA
# 396         478   Mountain Bottle Cage  Mountain Bottle Cage     NA
#
#     size_range       cost  normal_price       sub_category     category
# 0     42-46 CM  4811094.4     7559860.0         Road Bikes        Bikes
# 1     48-52 CM  4811094.4     7559860.0         Road Bikes        Bikes
# 2     48-52 CM  4811094.4     7559860.0         Road Bikes        Bikes
# 3     54-58 CM  4811094.4     7559860.0         Road Bikes        Bikes
# 4     42-46 CM  5784048.2     9787374.8         Road Bikes        Bikes
# ..         ...        ...           ...                ...          ...
# 392         NA   170693.6      456400.0    Tires and Tubes  Accessories
# 393         NA   183260.0      490000.0    Tires and Tubes  Accessories
# 394         NA    26128.2       69860.0  Bottles and Cages  Accessories
# 395         NA    47072.2      125860.0  Bottles and Cages  Accessories
# 396         NA    52308.2      139860.0  Bottles and Cages  Accessories
#
# [397 rows x 9 columns]

# %% [markdown]
# ##Play 1 - Select All
#
# ---

# %% [markdown]
# ### ***Get to know dim_territory***
#
# dim_territory adalah tabel dimensi yg digunakan BeeCycle untuk merecord wilayah operasi mereka (atau istilah lain toko cabang) beberapa informasi yg disimpan seperti
#
# * territory_id (identifier)
# * region (nama wilayah)
# * country (nama negara)
# * groups (group wilayah)

# %% [markdown]
# ⭐ Question
#
#
# **`Karena ingin mengetahui BeeCycle lebih dalam, kamu ingin melihat dimana saja territory Bee Cycle beroperasi?`**

# %% [markdown]
# ![dim_territory.PNG](data:image/png;base64,...)

# %% [markdown]
# * select **all column** dari tabel **dim_territory**

# %%
# write your SQL code here (hint select *)
# %%bigquery --project sonic-utility-323206
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     territory_id          region         country         groups
# 0             11              NA              NA             NA
# 1              7          France          France         Europe
# 2              8         Germany         Germany         Europe
# 3             10  United Kingdom  United Kingdom         Europe
# 4              9       Australia       Australia        Pacific
# 5              1       Northwest   United States  North America
# 6              2       Northeast   United States  North America
# 7              3         Central   United States  North America
# 8              4       Southwest   United States  North America
# 9              5       Southeast   United States  North America
# 10             6          Canada          Canada  North America

# %% [markdown]
# Sekarang kita tahu kalau Bee Cycle punya beberapa toko cabang. Bee Cycle menjalankan bisnisnya di America, Europe, dan Australia

# %% [markdown]
# Kamu juga bisa select * (all) pada table lain untuk mengenal database bee-cycle lebih detail

# %% [markdown]
# ## Play 2 - Select Distinct

# %% [markdown]
# ### ***Get to know dim_geography***

# %% [markdown]
# dim_geography adalah tabel dimensi atau tabel master untuk menyimpan informasi lokasi customer seperti
# * city (kota)
# * state_province_code (kode provinsi)
# * state_province_name (nama province)
# * country region code (kode negara)
# * english_country_region_name (nama negara)
# * postal code (kode pos)

# %% [markdown]
# ⭐ Question
#
# **`kamu kepo banget nih.. customer nya bee cycle tersebar di negara mana saja ya?`**

# %% [markdown]
# ![dim_geography.PNG](data:image/png;base64,...)

# %% [markdown]
# Tampilkan all column english_country_region_name terlebih dahulu tanpa distinct

# %%
# -- Write your Query here 
# %%bigquery --project sonic-utility-323206
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     english_country_region_name
# 0                     Australia
# 1                     Australia
# 2                     Australia
# 3                     Australia
# 4                     Australia
# ..                          ...
# 649               United States
# 650               United States
# 651               United States
# 652               United States
# 653               United States
#
# [654 rows x 1 columns]

# %% [markdown]
# Tampilkan secara unique kolom negara (english_country_region_name)

# %%
# -- Write your Query here 
# column : english_country_region_name 
# hint : distinct

# %%bigquery --project sonic-utility-323206

select distinct english_country_region_name
from dibimbing.dim_geography
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   english_country_region_name
# 0                   Australia
# 1                      Canada
# 2                     Germany
# 3                      France
# 4              United Kingdom
# 5               United States

# %% [markdown]
# Apa perbedaannya jika tanpa distinct ?

# %%
# -- Write your Query here 
# column : english_country_region_name 
# hint :without distinct

# %%bigquery --project sonic-utility-323206

# %% [markdown]
# ## Play 3 - Select Group By

# %% [markdown]
# ### ***Get to know dim_product***
#
# Selanjutnya agar bisa mengenal Bee Cycle lebih2 lagi, kamu ingin tahu Bee Cycle ini menjual product category apa saja ya?

# %% [markdown]
# dim product digunakan untuk merecord semua product yg dijual oleh BeeCycle. dibimbing.dim_product menyimpan segala macam informasi product seperti
# * product_name,
# * model_name,
# * color,
# * size_range,
# * cost (biaya produksi),
# * normal price (harga jual),
# * sub category, dan
# * category dari product

# %% [markdown]
# tunggu dulu... selain menggunakan SELECT DISTINCT ,
# kita juga bisa menggunakan **GROUP BY** untuk menampilkan column secara unique.

# %% [markdown]
# ⭐ Question
#
# **`Apa aja sih category product yg dijual oleh bee-cycle`**
#
#
# * column : category, sub_category
# * hint : group by

# %% [markdown]
# ![dim_product.PNG](data:image/png;base64,...)

# %%
# -- Write your Query here

# %%bigquery --project sonic-utility-323206
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        category       sub_category
# 0         Bikes         Road Bikes
# 1         Bikes      Touring Bikes
# 2         Bikes     Mountain Bikes
# 3      Clothing               Caps
# 4      Clothing              Socks
# 5      Clothing              Vests
# 6      Clothing             Gloves
# 7      Clothing             Shorts
# 8      Clothing             Tights
# 9      Clothing            Jerseys
# 10     Clothing         Bib-Shorts
# 11   Components              Forks
# 12   Components             Brakes
# 13   Components             Chains
# 14   Components             Pedals
# 15   Components             Wheels
# 16   Components            Saddles
# 17   Components           Headsets
# 18   Components          Cranksets
# 19   Components         Handlebars
# 20   Components        Derailleurs
# 21   Components        Road Frames
# 22   Components     Touring Frames
# 23   Components    Bottom Brackets
# 24   Components    Mountain Frames
# 25  Accessories              Locks
# 26  Accessories              Pumps
# 27  Accessories             Lights
# 28  Accessories            Fenders
# 29  Accessories            Helmets
# 30  Accessories           Cleaners
# 31  Accessories           Panniers
# 32  Accessories         Bike Racks
# 33  Accessories        Bike Stands
# 34  Accessories    Hydration Packs
# 35  Accessories    Tires and Tubes
# 36  Accessories  Bottles and Cages

# %% [markdown]
# Apakah perbedaannya jika tanpa group by ?

# %%
# -- Write your Query here (tanpa group by )
# %%bigquery --project sonic-utility-323206

# %% [markdown]
# ##Play 4 - Select Order By

# %% [markdown]
# ### ***Get to know dim_customer***

# %% [markdown]
# dim customer adalah tabel untuk menyimpan semua informasi customer BeeCycle. Beberapa informasi yg tersimpan misalnya
# * customer_id,
# * geography_id,
# * customer_name,
# * tanggal lahir (birthdate),
# * maritalstatus (status pernikahan),
# * gender, dan
# * datefirstpurchase (tgl pertama kali transaksi)

# %% [markdown]
# ⭐ Question
#
# **`Selanjutnya kamu ingin mengetahui siapa saja customer2 BeeCycle `**
#
# **`jika diurutkan berdasarkan tahun purchase terlama?`**

# %% [markdown]
# * column : all
# * hint : order by desc / asc (column : datefirstpurchase)

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
# -- Write your Query here
# %%bigquery --project sonic-utility-323206
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       customer_id  geography_id     customer_name   birthdate maritalstatus  \
# 0           11003            11       Christy Zhu  1988-02-15             S
# 1           28389           222  Rachael Martinez  1984-12-18             S
# 2           11011            22         Curtis Lu  1983-11-04             M
# 3           11005            22        Julio Ruiz  1985-08-05             S
# 4           13591           278    Latasha Alonso  1973-05-25             M
# ...           ...           ...               ...         ...           ...
# 1352        11562           158   Jarrod Gonzalez  1986-04-19             M
# 1353        11024           311       Russell Xie  1998-09-17             M
# 1354        12665            33        Joy Suarez  1995-10-05             M
# 1355        11306           312        Micah Zhou  1980-06-22             M
# 1356        11280           626    Robert Collins  1983-08-21             M
#
#      gender datefirstpurchase
# 0         F        2016-07-01
# 1         F        2016-07-01
# 2         M        2016-07-02
# 3         M        2016-07-02
# 4         F        2016-07-05
# ...     ...               ...
# 1352      M        2018-12-28
# 1353      M        2018-12-29
# 1354      F        2018-12-31
# 1355      M        2019-01-01
# 1356      M        2019-01-02
#
# [1357 rows x 7 columns]

# %% [markdown]
# ⭐ Question (coba lagi)
#
# **`Selanjutnya kamu ingin mengetahui siapa saja customer2 BeeCycle `**
#
# **`jika diurutkan berdasarkan tahun purchase terlama, `**
#
# **`lalu diurutkan juga berdasarkan alfabet customer_name ?`**

# %%
# -- Write your Query here
# %%bigquery --project sonic-utility-323206
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       customer_id     customer_name datefirstpurchase
# 0           28389  Rachael Martinez        2016-07-01
# 1           11003       Christy Zhu        2016-07-01
# 2           11005        Julio Ruiz        2016-07-02
# 3           11011         Curtis Lu        2016-07-02
# 4           27601     Sydney Rogers        2016-07-05
# ...           ...               ...               ...
# 1352        11562   Jarrod Gonzalez        2018-12-28
# 1353        11024       Russell Xie        2018-12-29
# 1354        12665        Joy Suarez        2018-12-31
# 1355        11306        Micah Zhou        2019-01-01
# 1356        11280    Robert Collins        2019-01-02
#
# [1357 rows x 3 columns]

# %% [markdown]
# Apakah perbedaannya?

# %% [markdown]
# ## Play 5 - Select Limit

# %% [markdown]
# ### ***Get to know fact_sales***

# %% [markdown]
# fact sales adalah tabel transaksi dimana menyimpan semua informasi transaksi seperti
#
# *   order_date (tanggal transaksi)
# *   product_id (product identifier yg dibeli pada transaksi)
# *   customer_id (customer identifier yg melalukan pembelian)
# *   territory_id (territory identifier untuk mengidentifikasi toko cabang transaksi)
# *   sales_order_number (nomor sales order)
# *   sales_order_line_number (jumlah line product pada 1 sales order)
# *   quantity (jumlah quantity 1 product yg dibeli)
# *   unitprice_rupiah (harga per 1 product)
# *   totalprice_rupiah (harga product * quantity atau harga total per product)
# *   totalcost_rupiah (biaya total per product)
# *   shippingprice_rupiah (biaya shipping per product)

# %% [markdown]
# ⭐ Question
#
# **`Bagaimana ya detail TOP 5 transaction diurutkan dari order_date terlama?`**
#
# **`(kepo sama jenis transaksi pertama nya bee cycle nich)`**

# %% [markdown]
# * column : all
# * hint : order by order_date (asc / desc)
# * hint : top 5 using limit

# %% [markdown]
# ![fact_sales.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT *
# FROM dibimbing.fact_sales
# order by order_date
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   order_detail_id  order_date  product_id  customer_id  territory_id  \
# 0       SO43698-1  2016-07-01         346        28389             7
# 1       SO43705-1  2016-07-02         344        11011             9
# 2       SO43704-1  2016-07-02         351        11005             9
# 3       SO43714-1  2016-07-05         311        13591            10
# 4       SO43713-1  2016-07-05         310        27601             4
#
#   sales_order_number  sales_order_line_number  quantity  unitprice_rupiah  \
# 0            SO43698                        1         1        47599860.0
# 1            SO43705                        1         1        47599860.0
# 2            SO43704                        1         1        47249860.0
# 3            SO43714                        1         1        50095780.0
# 4            SO43713                        1         1        50095780.0
#
#    totalprice_rupiah  totalcost_rupiah  shippingprice_rupiah
# 0         47599860.0        26770161.6             1189997.2
# 1         47599860.0        26770161.6             1189997.2
# 2         47249860.0        26573321.6             1181247.2
# 3         50095780.0        30398118.8             1252395.2
# 4         50095780.0        30398118.8             1252395.2

# %% [markdown]
# **Horraayyy..**
#
#
# ---
#
#
# **sekarang kita lebih mengenal tabel2 yg sedang kita hadapi..**

# %% [markdown]
# # Basic SQL

# %% [markdown]
# ![Basic - Select Statement.PNG](data:image/png;base64,...)

# %%
# format statement 

# %%bigquery --project sonic-utility-323206

# %% [markdown]
# #Where Clause AND / OR / IN

# %% [markdown]
# *   **AND**	-> Logical operator AND
# *   **OR** ->	Logical operator OR
# *   **IN** ->	Return true if a value matches any value in a list

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT
# FROM
# WHERE conditon1 AND condition2 OR condition3

# %% [markdown]
# ## Conditional - AND

# %% [markdown]
# ![where condition - AND.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question
#
# **`Apa aja sih product yg dijual sama BeeCycle dari category Clothing dan berwarna biru? `**

# %% [markdown]
# * Query all column pada tabel **dim_product** .
# * namun hanya pada **category** Clothing dan memiliki **warna** Biru

# %% [markdown]
# ![dim_product.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
# SELECT *
# from dibimbing-386613.dibimbing.dim_product
# where category = "Clothing"
# and color = "Blue"
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    product_id     product_name    model_name color size_range      cost  \
# 0         473  Classic Vest, L  Classic Vest  Blue          L  332486.0
# 1         472  Classic Vest, M  Classic Vest  Blue          M  332486.0
# 2         471  Classic Vest, S  Classic Vest  Blue          S  332486.0
#
#    normal_price sub_category  category
# 0      889000.0        Vests  Clothing
# 1      889000.0        Vests  Clothing
# 2      889000.0        Vests  Clothing

# %%
# %%bigquery --project sonic-utility-323206

# %% [markdown]
# ## Conditional - OR

# %% [markdown]
# ![where condition.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question
#
# **`Gajian masih lama siss.. tapi perlu kasih hadian buat teman terdekat.. akhirnya kamu gali2 data dim product nya BeeCycle siapa tahu nemu product yg cocok dengan harga sesuai budget`**
#
# ---
#
# **`Top 10 product paling murah yg dijual sama Bee-Cycle apa ya? Kebetulan temenku sukanya cuma category : Clothing atau Component atau Accessories`**

# %% [markdown]
# * Query all column dari tabel **dim_product**
# * filter hanya untuk **category** Clothing, Components, dan Accessories ,  -> menggunakan **OR** function
# * sort by yg memiliki normal price **termurah (ASC)**
# * dan hanya (**LIMIT 10** saja)

# %% [markdown]
# ![dim_product.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT *
# from dibimbing-386613.dibimbing.dim_product
# where category = "Clothing"
# OR category = 'Components'
# or category = 'Accessories'
# order by normal_price asc
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    product_id               product_name          model_name  color  \
# 0         211    HL Road Frame - Red, 58       HL Road Frame    Red
# 1         210  HL Road Frame - Black, 58       HL Road Frame  Black
# 2         480        Patch Kit/8 Patches           Patch kit     NA
# 3         529             Road Tire Tube      Road Tire Tube     NA
# 4         477      Water Bottle - 30 oz.        Water Bottle     NA
# 5         530          Touring Tire Tube   Touring Tire Tube     NA
# 6         528         Mountain Tire Tube  Mountain Tire Tube     NA
# 7         484      Bike Wash - Dissolver           Bike Wash     NA
# 8         224               AWC Logo Cap         Cycling Cap  Multi
# 9         223               AWC Logo Cap         Cycling Cap  Multi
#
#   size_range     cost  normal_price       sub_category     category
# 0   54-58 CM  11000.0       11000.0        Road Frames   Components
# 1   54-58 CM  11000.0       11000.0        Road Frames   Components
# 2         NA  11991.0       32060.0    Tires and Tubes  Accessories
# 3         NA  20892.2       55860.0    Tires and Tubes  Accessories
# 4         NA  26128.2       69860.0  Bottles and Cages  Accessories
# 5         NA  26128.2       69860.0    Tires and Tubes  Accessories
# 6         NA  26128.2       69860.0    Tires and Tubes  Accessories
# 7         NA  41626.2      111300.0           Cleaners  Accessories
# 8         NA  73215.8      121018.8               Caps     Clothing
# 9         NA  79872.8      121018.8               Caps     Clothing

# %% [markdown]
# ## Conditional - IN()

# %% [markdown]
# ![VALUE IN.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question (masih question yg sama)
#
#
# **`Gajian masih lama siss.. tapi perlu kasih hadian buat teman terdekat.. akhirnya kamu gali2 data dim product nya BeeCycle siapa tahu nemu product yg cocok dengan harga sesuai budget`**
#
# ---
#
# **`Top 10 product paling murah yg dijual sama Bee-Cycle apa ya? Kebetulan temenku sukanya cuma category : Clothing atau Component atau Accessories`**

# %% [markdown]
# * Query all column dari tabel **dim_product**
# * filter hanya untuk **category** Clothing, Components, dan Accessories ,  -> menggunakan **OR** function
# * sort by yg memiliki normal price **termurah (ASC)**
# * dan hanya (**LIMIT 10** saja)

# %% [markdown]
# ![dim_product.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT *
# from dibimbing-386613.dibimbing.dim_product
# where category in ("Clothing", "Components", "Accessories")
# order by normal_price asc
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    product_id               product_name          model_name  color  \
# 0         211    HL Road Frame - Red, 58       HL Road Frame    Red
# 1         210  HL Road Frame - Black, 58       HL Road Frame  Black
# 2         480        Patch Kit/8 Patches           Patch kit     NA
# 3         529             Road Tire Tube      Road Tire Tube     NA
# 4         477      Water Bottle - 30 oz.        Water Bottle     NA
# 5         530          Touring Tire Tube   Touring Tire Tube     NA
# 6         528         Mountain Tire Tube  Mountain Tire Tube     NA
# 7         484      Bike Wash - Dissolver           Bike Wash     NA
# 8         224               AWC Logo Cap         Cycling Cap  Multi
# 9         223               AWC Logo Cap         Cycling Cap  Multi
#
#   size_range     cost  normal_price       sub_category     category
# 0   54-58 CM  11000.0       11000.0        Road Frames   Components
# 1   54-58 CM  11000.0       11000.0        Road Frames   Components
# 2         NA  11991.0       32060.0    Tires and Tubes  Accessories
# 3         NA  20892.2       55860.0    Tires and Tubes  Accessories
# 4         NA  26128.2       69860.0  Bottles and Cages  Accessories
# 5         NA  26128.2       69860.0    Tires and Tubes  Accessories
# 6         NA  26128.2       69860.0    Tires and Tubes  Accessories
# 7         NA  41626.2      111300.0           Cleaners  Accessories
# 8         NA  73215.8      121018.8               Caps     Clothing
# 9         NA  79872.8      121018.8               Caps     Clothing

# %% [markdown]
# #Value Comparison

# %% [markdown]
# Digunakan untuk melakukan filter pada kondisi nilai tertentu

# %% [markdown]
# ![Value comparison.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT [nama column]
# FROM [nama table]
# WHERE
# column_name [operator] value

# %% [markdown]
# ## Value Comparison (Equal = )

# %% [markdown]
# ⭐ Question
#
#
# **`Sekarang kamu kepo nih sama harga-harga sepeda di Bee..`**
#
# **`Ada gak ya product category Component yg punya harga 11000 perak ???`**

# %% [markdown]
# * Query all column dari **dim_product**
# * Filter hanya yg memiliki normal_price = 11000,
# * dan hanya untuk **category** Components

# %% [markdown]
# ![dim_product.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT *
# from dibimbing-386613.dibimbing.dim_product
# where normal_price = 11000
# and category = 'Components'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    product_id               product_name     model_name  color size_range  \
# 0         210  HL Road Frame - Black, 58  HL Road Frame  Black   54-58 CM
# 1         211    HL Road Frame - Red, 58  HL Road Frame    Red   54-58 CM
#
#       cost  normal_price sub_category    category
# 0  11000.0       11000.0  Road Frames  Components
# 1  11000.0       11000.0  Road Frames  Components

# %% [markdown]
# ## Value Comparison (Not Equal <> or != )

# %% [markdown]
# ⭐ Question
#
#
# **`Sekarang kamu kepo nih sama harga-harga sepeda di Bee..`**
#
# **`Ada gak ya product category Component yg punya harga SELAIN 11000 perak ???`**

# %% [markdown]
# * Query all column dari tabel **dim_product**
# * yang memiliki harga **tidak sama dengan 11000**
# * dan dari **category** Components ,
# * urutkan berdasarkan product_id (ASC)
# * dan hanya TOP 10 (Limit 10)

# %% [markdown]
# ![dim_product.PNG](data:image/png;base64,...)

# %% [markdown]
# gunakan <>

# %%
# %%bigquery --project sonic-utility-323206
# SELECT *
# from dibimbing-386613.dibimbing.dim_product
# where normal_price <> 11000
# and category = 'Components'
# order by product_id asc
# limit 10

# %% [markdown]
# gunakan !=

# %%
# %%bigquery --project sonic-utility-323206
#
# select *
# from dibimbing.dim_product
# where normal_price != 11000
# and category = 'Components'
# order by product_id asc
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    product_id             product_name     model_name color size_range  \
# 0         238  HL Road Frame - Red, 62  HL Road Frame   Red   60-62 CM
# 1         239  HL Road Frame - Red, 62  HL Road Frame   Red   60-62 CM
# 2         240  HL Road Frame - Red, 62  HL Road Frame   Red   60-62 CM
# 3         241  HL Road Frame - Red, 44  HL Road Frame   Red   42-46 CM
# 4         242  HL Road Frame - Red, 44  HL Road Frame   Red   42-46 CM
# 5         243  HL Road Frame - Red, 44  HL Road Frame   Red   42-46 CM
# 6         244  HL Road Frame - Red, 48  HL Road Frame   Red   48-52 CM
# 7         245  HL Road Frame - Red, 48  HL Road Frame   Red   48-52 CM
# 8         246  HL Road Frame - Red, 48  HL Road Frame   Red   48-52 CM
# 9         247  HL Road Frame - Red, 52  HL Road Frame   Red   48-52 CM
#
#          cost  normal_price sub_category    category
# 0  10471554.8    17688437.2  Road Frames  Components
# 1  10111595.2    18219090.4  Road Frames  Components
# 2  12160878.8    20041000.0  Road Frames  Components
# 3  10471554.8    17688437.2  Road Frames  Components
# 4  10111595.2    18219090.4  Road Frames  Components
# 5  12160878.8    20041000.0  Road Frames  Components
# 6  10471554.8    17688437.2  Road Frames  Components
# 7  10111595.2    18219090.4  Road Frames  Components
# 8  12160878.8    20041000.0  Road Frames  Components
# 9  10471554.8    17688437.2  Road Frames  Components

# %% [markdown]
# ## Value Comparison (Less / Greater)

# %% [markdown]
# ⭐ Question
#
#
# **`Berhubung masih awal bulan, masih lama gajian.. `**
#
# **`kamu kepo ada gak ya komponen sepeda seharga < 20 ribu, dan bakal dapat barang apa itu yaw???`**

# %% [markdown]
# * Query all column dari tabel **dim_product**
# * yang memiliki harga **kurang dari sama dengan 20 ribu**
# * dan dari **category** Components ,
# * urutkan berdasarkan product_id (ASC)
# * dan hanya TOP 10 (Limit 10)

# %% [markdown]
# ![dim_product.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
# SELECT *
# from dibimbing-386613.dibimbing.dim_product
# where normal_price <= 20000
# and category = 'Components'
# order by product_id asc
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    product_id               product_name     model_name  color size_range  \
# 0         210  HL Road Frame - Black, 58  HL Road Frame  Black   54-58 CM
# 1         211    HL Road Frame - Red, 58  HL Road Frame    Red   54-58 CM
#
#       cost  normal_price sub_category    category
# 0  11000.0       11000.0  Road Frames  Components
# 1  11000.0       11000.0  Road Frames  Components

# %% [markdown]
# Silahkan explore untuk fungsi yg lain
# * Less than (<)
# * Less than or Equal (<=)
# * Greater than (>)
# * Greater than or Equal (>=)

# %%
# %%bigquery --project sonic-utility-323206

# %% [markdown]
# ## Value Comparison (Between)

# %% [markdown]
# ⭐ Question
#
#
# **`Mengingat budget di kantong saat ini, akhrnya kamu memustuskan untuk`**
#
# **`Yaudah beli sepeda yg antara 1 juta sampai 10juta, dapat apa ya???`**

# %% [markdown]
# * Query all column dari tabel **dim_product**
# * dengan harga normal price antara 1juta  dan 10juta (use >= and <= )

# %% [markdown]
# ![dim_product.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT *
# from dibimbing-386613.dibimbing.dim_product
# where normal_price >= 1000000 and normal_price <= 10000000
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      product_id                      product_name              model_name  \
# 0           604                Road-750 Black, 44                Road-750
# 1           605                Road-750 Black, 48                Road-750
# 2           606                Road-750 Black, 52                Road-750
# 3           584                Road-750 Black, 58                Road-750
# 4           326                  Road-650 Red, 44                Road-650
# ..          ...                               ...                     ...
# 138         512  ML Mountain Frame-W - Silver, 42     ML Mountain Frame-W
# 139         513  ML Mountain Frame-W - Silver, 46     ML Mountain Frame-W
# 140         446           Touring-Panniers, Large        Touring-Panniers
# 141         483               Hitch Rack - 4-Bike     Hitch Rack - 4-Bike
# 142         486            All-Purpose Bike Stand  All-Purpose Bike Stand
#
#       color size_range       cost  normal_price     sub_category     category
# 0     Black   42-46 CM  4811094.4     7559860.0       Road Bikes        Bikes
# 1     Black   48-52 CM  4811094.4     7559860.0       Road Bikes        Bikes
# 2     Black   48-52 CM  4811094.4     7559860.0       Road Bikes        Bikes
# 3     Black   54-58 CM  4811094.4     7559860.0       Road Bikes        Bikes
# 4       Red   42-46 CM  5784048.2     9787374.8       Road Bikes        Bikes
# ..      ...        ...        ...           ...              ...          ...
# 138  Silver   42-46 CM  2791259.8     5097260.0  Mountain Frames   Components
# 139  Silver   42-46 CM  2791259.8     5097260.0  Mountain Frames   Components
# 140    Grey         NA   721875.0     1750000.0         Panniers  Accessories
# 141      NA         NA   628320.0     1680000.0       Bike Racks  Accessories
# 142      NA         NA   832524.0     2226000.0      Bike Stands  Accessories
#
# [143 rows x 9 columns]

# %% [markdown]
# * Query all column dari tabel **dim_product**
# * dengan harga normal price antara 1juta  dan 10juta (use BETWEEN)

# %%
# %%bigquery --project sonic-utility-323206
#
# select *
# from dibimbing.dim_product
# where normal_price between 1000000 and 10000000
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      product_id                      product_name              model_name  \
# 0           604                Road-750 Black, 44                Road-750
# 1           605                Road-750 Black, 48                Road-750
# 2           606                Road-750 Black, 52                Road-750
# 3           584                Road-750 Black, 58                Road-750
# 4           326                  Road-650 Red, 44                Road-650
# ..          ...                               ...                     ...
# 138         512  ML Mountain Frame-W - Silver, 42     ML Mountain Frame-W
# 139         513  ML Mountain Frame-W - Silver, 46     ML Mountain Frame-W
# 140         446           Touring-Panniers, Large        Touring-Panniers
# 141         483               Hitch Rack - 4-Bike     Hitch Rack - 4-Bike
# 142         486            All-Purpose Bike Stand  All-Purpose Bike Stand
#
#       color size_range       cost  normal_price     sub_category     category
# 0     Black   42-46 CM  4811094.4     7559860.0       Road Bikes        Bikes
# 1     Black   48-52 CM  4811094.4     7559860.0       Road Bikes        Bikes
# 2     Black   48-52 CM  4811094.4     7559860.0       Road Bikes        Bikes
# 3     Black   54-58 CM  4811094.4     7559860.0       Road Bikes        Bikes
# 4       Red   42-46 CM  5784048.2     9787374.8       Road Bikes        Bikes
# ..      ...        ...        ...           ...              ...          ...
# 138  Silver   42-46 CM  2791259.8     5097260.0  Mountain Frames   Components
# 139  Silver   42-46 CM  2791259.8     5097260.0  Mountain Frames   Components
# 140    Grey         NA   721875.0     1750000.0         Panniers  Accessories
# 141      NA         NA   628320.0     1680000.0       Bike Racks  Accessories
# 142      NA         NA   832524.0     2226000.0      Bike Stands  Accessories
#
# [143 rows x 9 columns]

# %% [markdown]
# ## Value Comparison - Join Statement

# %% [markdown]
# ⭐ Question
#
#
# **`Untuk memperingati hari kemerdekaan, BeeCycle mau pasang promo menarik nih, tapi hanya untuk product-product yg punya performance bagus aja aka lebih populer dibeli sama orang-orang. `**
#
# **`TOP 10 product name apa ya yg paling banyak di beli???`**

# %% [markdown]
# * Query column : product_name, model_name, color, sub_category, category dari **dim_product**,
# * hitung jumlah transaksi dari tabel **fact_sales** dengan count(distinct order_detail_id)
# * join hint : product_id
# * Selanjutnya urutkan product dari jumlah transaksi terbesar ke kecil **(DESC)**
# * dan hanya ambil TOP 10 (Limit 10)

# %% [markdown]
# jumlah transaksi = count distinct order_detail_id

# %% [markdown]
# ![dim product x fact sales.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206

# %% [markdown]
# # String Pattern

# %% [markdown]
# * Fungsi **LIKE** mengembalikan nilai true jika string **cocok** dengan pola yang disediakan.
#
# * Fungsi **NOT LIKE** mengembalikan nilai true jika string **tidak cocok** dengan pola yang disediakan.

# %%
# %%bigquery --project sonic-utility-323206
#
# select customer_name
# from dibimbing-386613.dibimbing.dim_customer
# where customer_name like 'Jon%'
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         customer_name
# 0             Jon Gao
# 1            Jon Yang
# 2            Jon Zhou
# 3             Jon Luo
# 4  Jonathan Henderson
# 5         Jon Chander
# 6      Jonathan Perry
# 7   Jonathan Gonzales
# 8       Jonathan Shan
# 9            Jon Zhao

# %% [markdown]
# Kita juga dapat menggunakan % dan _ untuk membuat pola :

# %% [markdown]
# *   Tanda % (persen) berfungsi untuk mewakili nol atau lebih karakter
# *   Tanda _ (garis bawah / underscore) berfungsi mewakili satu karakter

# %% [markdown]
# Jika pola tidak mengandung tanda persen atau garis bawah, maka pola yg dimaksud adalah string itu sendiri;

# %% [markdown]
# ![String Pattern.PNG](data:image/png;base64,...)

# %% [markdown]
# ##String Pattern 1

# %% [markdown]
# ⭐ Question
#
# Promo Random Sedunia! Hanya customer yg memiliki **nama depan Cameron** akan mendapatkan diskon 100% dengan maksimal diskon 1juta.
#
#
# **`Siapa aja customer kita yg punya nama depan Cameron?`**

# %% [markdown]
# * Query customer_id, dan customer_name dari tabel **dim_customer**
# * dan hanya filter nama customer yg memiliki **nama depan Cameron**

# %% [markdown]
# eg :
# * Cameron Diaz -> True
# * John Cameron -> False

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
# select customer_id, customer_name
# from dibimbing-386613.dibimbing.dim_customer
# where customer_name like 'Cameron%
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id      customer_name
# 0        16595   Cameron Anderson
# 1        11301  Cameron Rodriguez
# 2        15371     Cameron Bryant
# 3        28177  Cameron Henderson
# 4        11534      Cameron Lewis

# %% [markdown]
# ##String Pattern 2

# %% [markdown]
# ⭐ Question
#
# Lagi! Promo Random Sedunia! Promo buat nama belakang **Stone**
#
# **`Siapa aja customer kita yg punya nama belakang Stone?`**

# %% [markdown]
# * Query customer_id, dan customer_name dari tabel **dim_customer**
# * dan hanya filter nama customer yg memiliki **nama belakang Stone**

# %% [markdown]
# eg :
# * Louis Stone -> True
# * Stone Albert -> False

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id customer_name
# 0        11032  Denise Stone
# 1        12673   Colin Stone
# 2        28792   Henry Stone

# %% [markdown]
# ##String Pattern 3

# %% [markdown]
# ⭐ Question
#
# Di hari Promo Random Sedunia selanjutnya, nama ron terpilih. Promo akan diberikan kepada semua customer yg **mengandung 'ron'** pada namanya, entah di awal tengah atau akhir. Namun, karena nama Cameron sudah mendapatkan promo sebelumnya, **nama depan Cameron di exclude pada query ini**.
#
# **`Siapa aja customer kita yg mengandung 'ron' di namanya, kecuali nama depan cameron ?`**

# %% [markdown]
# * Query customer_id, dan customer_name dari tabel **dim_customer**
# * hanya filter nama customer yg mengandung kata **ron** baik di awal, tengah, akhir nama atau semuanya
# * namun tidak memiliki nama depan **Cameron**

# %% [markdown]
# eg :
# * Ron Weasley -> True
# * Aron Anjani -> True
# * Fabiola Roni -> True
# * Cameron Louis -> False

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# select customer_id, customer_name
# from dibimbing-386613.dibimbing.dim_customer
# where lower(customer_name) like '%ron%'
# and customer_name not like 'Cameron%'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     customer_id     customer_name
# 0         11122     Byron Vazquez
# 1         15429          Aaron Li
# 2         14719         Ronnie He
# 3         17891        Sharon Lal
# 4         14192     Ronald Kapoor
# 5         11900     Byron Carlson
# 6         11996    Veronica Srini
# 7         11964  Sharon Salavaria
# 8         11360    Tyrone Serrano
# 9         20075       Aaron Allen
# 10        14722     Sharon Carson
# 11        28573       Tyrone Gill
# 12        15684     Tyrone Suarez
# 13        16513     Ronnie Wagner
# 14        28707       Sharon Raje

# %% [markdown]
# ##String Pattern 4

# %% [markdown]
# ⭐ Question
#
# Promo random sedunia selanjutnya jatuh pada nama depan Jon. Tapi Jon yg ini harus punya nama akhir cuma 3 huruf.
#
# **`Siapa aja customer kita dengan nama depan 'Jon', dan punya nama akhir 3 huruf?`**

# %% [markdown]
# * Query customer_id, dan customer_name dari tabel **dim_customer**
# * hanya filter nama customer yg memiliki **nama depan Jon** serta **nama belakang 3 huruf**

# %% [markdown]
# eg :
# * Jon Lee -> True
# * Jon Louis -> False

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
#filter nama 2 kata yg mengandung underscore

# %%bigquery --project sonic-utility-323206 

select customer_id, customer_name
from dibimbing-386613.dibimbing.dim_customer
where lower(customer_name) like '%ron%'
and customer_name not like 'Cameron%'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id customer_name
# 0        11456       Jon Gao
# 1        11298       Jon Luo

# %% [markdown]
# ##String Pattern Join Statement

# %% [markdown]
# ⭐ Question
#
# Sekarang Promo Random Sedunia hanya untuk customer yg berada di wilayah Australia nih, untuk si nama belakang Stone
#
# **`Siapa aja customer kita dengan belakang 'Stone' dan tinggal di 'Australia??`**

# %% [markdown]
# * Query **customer_id, customer_name, nama province (state_province_name)** dari tabel **dim_customer** dan **dim_geography**
# * untuk customer_name dengan **nama belakang Stone**
# * dan tinggal di country_region_code **AU**

# %% [markdown]
# ![dim customer x dim geography.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206

# %% [markdown]
# # Aggregate Statement

# %% [markdown]
# ![aggregate 2.PNG](data:image/png;base64,...)

# %% [markdown]
# *  **AVG()** – return the average value.
# *  **COUNT(**) – return the number of values.
# *  **MAX()** – return the maximum value.
# *  **MIN()** – return the minimum value.
# *  **SUM()** – return the sum of all values.

# %%
# %%bigquery --project sonic-utility-323206
# SELECT SUM()
# FROM
# WHERE
# GROUP BY

# %% [markdown]
# ## Count(*)

# %% [markdown]
# Count(*) digunakan untuk menghitung jumlah baris (meskipun duplikat akan tetap dihitung)

# %% [markdown]
# ⭐ Question
#
# **`Berapa jumlah baris pada dibimbing.fact_sales ??`**

# %% [markdown]
# * Query count(tanda bintang) untuk menghitung total baris pada tabel **fact_sales**

# %% [markdown]
# ![fact_sales.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT count(*)
# from dibimbing-386613.dibimbing.fact_sales
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     f0_
# 0  5954

# %% [markdown]
# ##Count(DISTINCT)

# %% [markdown]
# * Count(Distinct) digunakan untuk menghitung jumlah baris secara unique
# * Selain Count, distinct juga berpengaruh terhadap operasi SUM atau AVG
# * Menggunakan distinct sebelum nama kolom dilakukan untuk menghindari duplikasi

# %% [markdown]
# ⭐ Question
#
#
# Untuk melihat performa buyer di BeeCycle kamu diminta untuk menarik jumlah unique buyer dari semua transaksi
#
# **`Berapa jumlah unique buyer yg dimiliki BeeCycle ???`**

# %% [markdown]
# * Query count(distinct) customer_id pada table **fact_sales**

# %% [markdown]
# ![fact_sales.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT count(distinct customer_id) as unique_buyer
# from dibimbing-386613.dibimbing.fact_sales
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    unique_buyer
# 0          1357

# %% [markdown]
# Untuk membandingkan, coba query ulang , namun tanpa menggunakan distinct
# sehinnga
# * Query count(tanpa distinct) customer_id pada table **fact_sales**
#
# bagaimana hasilnya?

# %%
# without distinct 
# %%bigquery --project sonic-utility-323206
SELECT count( customer_id) as non_unique_buyer
from dibimbing-386613.dibimbing.fact_sales
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    unique_buyer
# 0          5953

# %% [markdown]
# ## SUM & AVG

# %% [markdown]
# * SUM() berfungsi untuk mengembalikan jumlah nilai dalam kolom tertentu
# * AVG() berfungsi untuk mengembalikan nilai rata-rata dalam kolom tertentu

# %% [markdown]
# ⭐ Question
#
# Untuk mengetahui omset yg dihasilkan BeeCycle selama ini, kamu diminta tim finance buat tarik data tertentu ni
#
# **`Berapa jumlah total semua pendapatan yg dimiliki BeeCycle ???`**
#
# **`dan Berapa rata-rata pendapatan tiap transaksi yg dimiliki BeeCycle ???`**

# %% [markdown]
# * Query sum dari totalprice_rupiah pada tabel **fact_sales**
# * Di statement yg sama, ambil juga average dari totalprice_rupiah

# %% [markdown]
# ![fact_sales.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT sum(totalprice_rupiah) as total_sales,
# avg(totalprice_rupiah) as avg_sales
# from dibimbing-386613.dibimbing.fact_sales
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     total_sales     avg_sales
# 0  7.722612e+10  1.297046e+07

# %% [markdown]
# ##MAX & MIN

# %% [markdown]
# * MAX() berfungsi untuk mengembalikan nilai terbesar dari kolom tertentu
# * MIN() berfungsi untuk mengembalikan nilai terkecil dari kolom tertentu

# %% [markdown]
# ⭐ Question
#
# Untuk lebih mengetahui persebaran jenis customer dari BeeCycle kamu diminta untuk menarik tanggal lahir customer dari yg paling senior dan paling junior
#
# **`Kapan birthdate dari customer BeeCycle yg paling senior (max) ???`**
#
# **`Kapan birthdate dari customer BeeCycle yg paling junior (min) ???`**

# %% [markdown]
# * Query MAX dan MIN dari birthdate pada tabel **dim_customer**

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
#edited : max -> junior 

# %%bigquery --project sonic-utility-323206

SELECT min(birthdate) as senior, max(birthdate) junior
from dibimbing-386613.dibimbing.dim_customer
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        junior      senior
# 0  2000-11-06  1946-07-08

# %% [markdown]
# ##Group By

# %% [markdown]
# Group By adalah fungsi untuk mengelompokkan data dalam sebuah kolom. Dalam fungsi aggregate, penggunakan GROUP BY diperlukan apabila perhitungan dilakukan berdasarkan kelompok tertentu

# %% [markdown]
# ⭐ Question
#
# Agar strategi marketing yg dilakukan sesuai, kamu melihat persebaran jumlah customer pria dan wanita. Bagaimana ya perbandingannya kira2.. Banyak Pria atau Wanita?
#
# **`Berapa jumlah customer tiap gender???`**

# %% [markdown]
# * Query gender, beserta jumlah distinct customer_id tiap gender pada tabel **dim_customer**
# * Gunakan group by pada kolom yg ingin dihitung
# * Urutkan dari jumlah customer_id terbanyak (DESC)

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
# SELECT gender, count(distinct customer_id) as unique_buyer
# from dibimbing-386613.dibimbing.dim_customer
# group by gender
# order by count(distinct customer_id) desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   gender  jumlah_customer
# 0      M              665
# 1      F              695

# %% [markdown]
# ##Having

# %% [markdown]
# * Having digunakan bersama-sama GROUP BY untuk membatasi pengelompokkan yg ditampilkan pada tabel hasil akhir
# * Hampir seperti WHERE, dimana WHERE menyeleksi baris secara individual, sedangkan HAVING secara berkelompok

# %% [markdown]
# ⭐ Question
#
# **`Berapa jumlah customer tiap geography_id ???`**

# %% [markdown]
# * Query geograhy_id beserta jumlah distinct customer_id pada tabel **dim_customer**
# * Gunakan group by pada kolom yg ingin dihitung
# * Filter sehingga hasil aggregate hanya menampilkan geography_id yg memiliki unique customer >=15
# * Sort by jumlah customer tertinggi (DESC)

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# SELECT geography_id, count(distinct customer_id) as unique_buyer
# from dibimbing-386613.dibimbing.dim_customer
# group by geography_id
# having count(distinct customer_id) >= 15
# order by count(distinct customer_id) desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    geography_id  buyers
# 0           301      19
# 1            49      19
# 2            62      16
# 3           311      15

# %% [markdown]
# ##Group By Join Statement

# %% [markdown]
# ⭐ Question
#
# Untuk mengetahui performa BeeCycle tiap territory di tahun 2019, kamu diminta untuk query beberapa metrics buat si Bos ni.. Metrics yg dibutuhkan katanya Jumlah Transaksi, Omset (totalprice_rupiah), cost (totalcost_rupiah), dan profit (totalprice_rupiah - totalcost_rupiah)
#
# **`Berapa jumlah transaksi, omset, dan cost BeeCycle di tahun 2019???`**

# %% [markdown]
# * Query **tahun, territory_id** pada tabel **fact_sales** beserta metrics berikut
#   * Jumlah transaksi (order_detail)
#   * Omset (totalprice_rupiah)
#   * Profit (totalprice_rupiah - totalcost_rupiah)
# * Group by pada kolom yg dihitung
# * Hanya filter tahun 2019
# * Urutkan berdasarkan Tahun terkecil (ASC), Territory_id terkecil (ASC)

# %% [markdown]
# ![fact_sales.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206

# %% [markdown]
# #CASE WHEN

# %% [markdown]
# Ekspresi CASE PostgreSQL sama dengan pernyataan IF/ELSE dalam bahasa pemrograman lain. Ini memungkinkan Anda untuk menambahkan logika if-else ke kueri untuk membentuk kueri sesuai kebutuhan

# %% [markdown]
# CASE WHEN dapat digunakan pada klausa **SELECT, WHERE, GROUP BY, dan HAVING.**

# %% [markdown]
# ![case when 1.PNG](data:image/png;base64,...)

# %% [markdown]
# ## CASE WHEN SELECT

# %% [markdown]
# ⭐ Question
#
# Agar strategi marketing yg dilakukan sesuai, kamu ingin melihat persebaran jumlah customer pria dan wanita. Bagaimana ya perbandingannya kira2.. Banyak Pria atau Wanita?
#
# selain itu agar lebih user friendly, tampilkan hasilnya dengan mengubah M -> male_buyer dan F -> female_buyer
#
# **`Berapa jumlah customer tiap gender dan tiap wilayah???`**
#
# * Query count customer_id pada masing-masing gender dan geography_id
# * Gender M dirubah menjadi 'Male' dan dan 'F' dirubah menjadi 'Female' , selain itu 'Other'
# * Group by pada column yg dihitung (gender dan geography_id)

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# select
# case when gender = 'F' then 'Female'
#      when gender = 'M' then 'Male' end as gender,
#        geography_id,
#        count(distinct customer_id) unique_buyer
# from dibimbing-386613.dibimbing.dim_customer
# group by 1,2
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      gender  geography_id  buyers
# 0    Female             2       4
# 1    Female             3       3
# 2    Female             4       6
# 3    Female             5       5
# 4    Female             6       3
# ..      ...           ...     ...
# 462    Male           638       2
# 463    Male           641       4
# 464    Male           642       3
# 465    Male           644       4
# 466    Male           648       1
#
# [467 rows x 3 columns]

# %% [markdown]
# ## CASE WHEN IN AGGREGATE

# %% [markdown]
# ⭐ Question
#
# Agar strategi marketing yg dilakukan sesuai, kamu melihat persebaran jumlah customer pria dan wanita. Bagaimana ya perbandingannya kira2.. Banyak Pria atau Wanita?
#
# selain itu agar lebih user friendly, tampilkan hasilnya dengan mengubah M -> male_buyer dan F -> female_buyer
#
# **`Berapa jumlah customer tiap gender dan tiap wilayah???`**

# %% [markdown]
# Selanjutnya, persis seperti result sebelumnya, tapi kali ini tampilan yg diminta sedikit berbeda. Dari partner business kamu, mereka menghendaki tampilan query akan seperti dibawah ini

# %% [markdown]
# ![case when 2.PNG](data:image/png;base64,...)

# %% [markdown]
# * Query count customer_id pada masing-masing gender pada tabel **dim_customer** seperti output pada gambar diatas
# * Group by pada column yg dihitung (geography_id)

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# select geography_id,
# count(distinct case when gender = 'M' then customer_id end) male_buyer,
# count(distinct case when gender = 'F' then customer_id end)  female_buyer,
# count(distinct case when gender NOT IN ('M',"F") then customer_id end)  other_buyer
# from dibimbing-386613.dibimbing.dim_customer
# group by 1
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      geography_id  buyer_female  buyer_male  buyer_other
# 0             257             1           1            0
# 1               2             4           5            0
# 2             258             0           1            0
# 3               3             3           5            0
# 4             259             2           2            0
# ..            ...           ...         ...          ...
# 274           232             1           0            0
# 275           239             0           1            0
# 276           244             0           1            0
# 277           252             0           1            0
# 278           253             1           0            0
#
# [279 rows x 4 columns]

# %% [markdown]
# #SUB QUERY

# %% [markdown]
# Subquery adalah kueri yang bersarang di dalam kueri lain seperti SELECT, INSERT, DELETE, dan UPDATE. Dalam tutorial ini, kita akan membahas penggunaanya dalam SELECT

# %% [markdown]
# ##Sub Query - Persamaan

# %% [markdown]
# ![subquery1.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question
#
# Kamu diminta untuk menarik performance omset customer_id, namun filter hanya customer id yg memiliki id terkecil (MIN) diantara yg lain
# eg : misalnya diantara id 11,12,13,14,15 hanya menampilkan customer_id no 11
#
# **`Berapa jumlah omset dari customer_id 'min' (customer_id dg nilai customer_id terkecil) di BeeCycle???`**

# %% [markdown]
# * Query customer_id, dan jumlah omset (sum totalprice_rupiah) dari tabel **fact_sales**
# * Namun filter hanya dari customer_id yg memiliki customer_id terkecil **(min(customer_id))** di tabel **dim_customer** **(*subquery*)**

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# select customer_id, sum(totalprice_rupiah) as omset
# from dibimbing-386613.dibimbing.fact_sales
# where customer_id = (select min(customer_id)
#                      from dibimbing-386613.dibimbing.dim_customer)
# group by 1
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id        omset
# 0        11000  115485860.0

# %% [markdown]
# Cte format

# %%
# %%bigquery --project sonic-utility-323206
#
# with minimum_cid as
# (select min(customer_id) customer_id
#                      from dibimbing-386613.dibimbing.dim_customer)
#
# select customer_id, sum(totalprice_rupiah) as omset
# from dibimbing-386613.dibimbing.fact_sales
# where customer_id = (select customer_id from minimum_cid)
# group by 1
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id        omset
# 0        11000  115485860.0

# %% [markdown]
# ##Sub Query - IN

# %% [markdown]
# ![subqueri in.PNG](data:image/png;base64,...)

# %% [markdown]
# Mirip dengan penggunaan IN pada bab Conditional Where Clause, pada subquery, IN bisa digunakan untuk filter variable dengan nilai atau formula tertentu

# %% [markdown]
# ⭐ Example
#
# karena ingin sebar promo bagi loyal customer. Kamu diminta untuk generate informasi2 customer id yg pernah belanja >= 50juta
#
# terdapat dua pertanyaan :
#
# **`Siapa saja customer_id yg pernah belanja >= 50 juta ???`**
#
# **`Siapa saja customer tersebut (informasi detail) ???`**

# %%
# dari tabel fact sales, mencari customer_id dengan belanja >= 50 juta

# %%bigquery --project sonic-utility-323206 

select customer_id
from dibimbing-386613.dibimbing.fact_sales
where totalprice_rupiah >= 50000000
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      customer_id
# 0          27605
# 1          28041
# 2          28148
# 3          28792
# 4          28833
# ..           ...
# 381        14941
# 382        14846
# 383        15632
# 384        15652
# 385        15662
#
# [386 rows x 1 columns]

# %% [markdown]
# Lalu selanjutnya secara manual menyalin customer_id diatas kedalam conditional IN

# %%
# %%bigquery --project sonic-utility-323206
#
# select *
# from dibimbing-386613.dibimbing.dim_customer
# where customer_id in (copy paste result sebelumnya)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id  geography_id    customer_name   birthdate maritalstatus  \
# 0        27605           638  Miguel Martinez  1977-01-22             M
# 1        28148           611         Jon Zhao  1984-02-19             S
# 2        28041           631   Rebecca Wright  1969-05-02             S
#
#   gender datefirstpurchase
# 0      M        2016-07-29
# 1      M        2016-09-19
# 2      F        2016-08-30

# %% [markdown]
# ***Kita bisa menggunakan SUB QUERY untuk menyelesaikan soal ini ***

# %% [markdown]
# ⭐ Example
#
# karena ingin sebar promo bagi loyal customer. Kamu diminta untuk generate informasi2 customer id yg memiliki total belanja >= 150juta
#
# **`Siapa saja list informasi detail customer yg memiliki pembelian >= 150juta di BeeCycle  ???`**

# %% [markdown]
# * Query all column pada **dim_customer**
# * Namun hanya filter customer_id yg pernah memiliki transaksi = 150juta pada tabel **fact_sales** (*subquery*)
# * Urutkan berdasarkan customer_id (ASC)
# * ambil limit 10

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# select *
# from dibimbing-386613.dibimbing.dim_customer
# where customer_id in (select customer_id
#                       from dibimbing-386613.dibimbing.fact_sales
#                       where totalprice_rupiah >= 50000000)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      customer_id  geography_id     customer_name   birthdate maritalstatus  \
# 0          15638           259           Rosa He  1961-07-26             M
# 1          14191           266    Derrick Martin  1971-01-15             M
# 2          15661           269  Brandon Robinson  1979-08-20             M
# 3          15657           271      Marcus Hayes  1980-06-20             M
# 4          13600           273        Marie Sanz  1971-02-19             M
# ..           ...           ...               ...         ...           ...
# 381        14195           247    Clinton Blanco  1970-05-04             S
# 382        14697           248    Nelson Jimenez  1992-02-10             S
# 383        14712           252        Eugene Liu  1991-11-22             S
# 384        15653           254      Gerald Madan  1981-06-07             S
# 385        14157           255         Willie Xu  1989-04-14             S
#
#     gender datefirstpurchase
# 0        F        2017-05-22
# 1        M        2016-10-12
# 2        M        2017-06-08
# 3        M        2017-05-08
# 4        F        2016-08-06
# ..     ...               ...
# 381      M        2016-10-23
# 382      M        2016-11-29
# 383      M        2016-11-20
# 384      M        2017-05-12
# 385      M        2016-10-11
#
# [386 rows x 7 columns]

# %%
# %%bigquery --project sonic-utility-323206
# with
# omset_50mio as
# (select customer_id
#                       from dibimbing-386613.dibimbing.fact_sales
#                       where totalprice_rupiah >= 50000000)
# select *
# from dibimbing-386613.dibimbing.dim_customer
# where customer_id in (select customer_id
#                       from omset_50mio)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      customer_id  geography_id     customer_name   birthdate maritalstatus  \
# 0          15638           259           Rosa He  1961-07-26             M
# 1          14191           266    Derrick Martin  1971-01-15             M
# 2          15661           269  Brandon Robinson  1979-08-20             M
# 3          15657           271      Marcus Hayes  1980-06-20             M
# 4          13600           273        Marie Sanz  1971-02-19             M
# ..           ...           ...               ...         ...           ...
# 381        14195           247    Clinton Blanco  1970-05-04             S
# 382        14697           248    Nelson Jimenez  1992-02-10             S
# 383        14712           252        Eugene Liu  1991-11-22             S
# 384        15653           254      Gerald Madan  1981-06-07             S
# 385        14157           255         Willie Xu  1989-04-14             S
#
#     gender datefirstpurchase
# 0        F        2017-05-22
# 1        M        2016-10-12
# 2        M        2017-06-08
# 3        M        2017-05-08
# 4        F        2016-08-06
# ..     ...               ...
# 381      M        2016-10-23
# 382      M        2016-11-29
# 383      M        2016-11-20
# 384      M        2017-05-12
# 385      M        2016-10-11
#
# [386 rows x 7 columns]

# %% [markdown]
# ##Sub Query - From Function

# %% [markdown]
# ![subquery from.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question
#
# Kamu diminta untuk query informasi customer, namun hanya dari customer yg memiliki umur diatas 56 tahun
#
# **`Siapa saja customer yg memiliki umur di atas 56 tahun ???`**

# %% [markdown]
# * **Membuat 1 Subquery** untuk mengambil customer_id, customer_name, dan age dari tabel **dim_customer**
# * Pada Query utama, select customer_id, customer_name, dan age dari subquery
# * dan hanya filter untuk age >= 56

# %% [markdown]
# ![dim_customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# select customer_id, customer_name, age
# from (select *,
#       date_diff(current_date, birthdate,year) age
#       from dibimbing-386613.dibimbing.dim_customer)
# where age >= 56
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      customer_id   customer_name  age
# 0          15638         Rosa He   62
# 1          24503        Laura Ma   62
# 2          18186  Lori Hernandez   56
# 3          11031   Theresa Ramos   56
# 4          11033      Jaime Nath   56
# ..           ...             ...  ...
# 140        14203  Seth Rodriguez   56
# 141        12254     Calvin Deng   60
# 142        12301    Nichole Nara   57
# 143        11554  Sydney Simmons   77
# 144        11351      Anne Ramos   64
#
# [145 rows x 3 columns]

# %%
#menggunakan CTE

# %%bigquery --project sonic-utility-323206 
with cte_age as 
(select *,
      date_diff(current_date, birthdate,year) age
      from dibimbing-386613.dibimbing.dim_customer)

select customer_id, customer_name, age
from cte_age
where age >= 56
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      customer_id   customer_name  age
# 0          15638         Rosa He   62
# 1          24503        Laura Ma   62
# 2          18186  Lori Hernandez   56
# 3          11031   Theresa Ramos   56
# 4          11033      Jaime Nath   56
# ..           ...             ...  ...
# 140        14203  Seth Rodriguez   56
# 141        12254     Calvin Deng   60
# 142        12301    Nichole Nara   57
# 143        11554  Sydney Simmons   77
# 144        11351      Anne Ramos   64
#
# [145 rows x 3 columns]

# %% [markdown]
# ## Sub Query (CTE)

# %% [markdown]
# ![subquery cte.PNG](data:image/png;base64,...)

# %% [markdown]
# A CTE (common table expression) is a named subquery defined in a WITH clause. You can think of the CTE as a temporary view for use in the statement that defines the CTE. The CTE defines the temporary view’s name, an optional list of column names, and a query expression (i.e. a SELECT statement). The result of the query expression is effectively a table.

# %% [markdown]
# ⭐ Question
#
# Kamu di minta bos buat tarik duit yg didapat dari customer paling junior
#
# **`Berapa jumlah omset yg diberikan oleh customer paling junior ke BeeCycle???`**

# %% [markdown]
# * Siapa customer paling junior?
#   * **Membuat 1 CTE** untuk mengambil customer_id paling junior (memiliki birthdate paling akhir (DESC) top 1 )
# * Berapa omset customer tsb?
#   * Lalu, pada main query, tampilkan customer_id, dan jumlah totalprice_rupiah (sum totalprice_rupiah) dari tabel **fact_sales**
#   * dan filter hanya untuk customer_id yg terdapat pada CTE step pertama (IN)

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# with
# junior as
# (select customer_id, birthdate
# from dibimbing-386613.dibimbing.dim_customer
# order by birthdate desc
# limit 1)
#
# select customer_id, sum(totalprice_rupiah) as omset
# from dibimbing-386613.dibimbing.fact_sales
# where customer_id = (select customer_id from junior)
# group by customer_id
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id       omset
# 0        22971  50095780.0

# %% [markdown]
# #JOIN

# %% [markdown]
# * PostgreSQL join digunakan untuk menggabungkan kolom dari satu atau lebih tabel berdasarkan nilai kolom antara tabel terkait.
# * Kolom yang biasanya dilakukan join adalah primary key dari tabel pertama dan foreign key dari tabel kedua.

# %% [markdown]
# ![join statement3.PNG](data:image/png;base64,...)

# %% [markdown]
# *  **LEFT JOIN** : perintah join untuk menampilkan semua data sebelah kiri dari table yang di joinkan dan menampilkan data sebelah kanan yang cocok dengan kondisi join. Jika tidak ditemukan kecocokan, maka akan di set NULL secara otomatis

# %% [markdown]
# *  **RIGHT JOIN** : menampilkan semua data yang ada di table sebelah kanan dan mencari kecocokan key pada table sebelah kiri, jika tidak ditemukan kecocokan, maka akan di set NULL secara otomatis pada table sebelah kiri.

# %% [markdown]
# *  **INNER JOIN / JOIN** : mengambil semua row dari table kiri dan table kanan dengan kondisi nilai key yang terkait saja, dan  jika tidak maka row tersebut tidak akan muncul.

# %% [markdown]
# *  **FULL JOIN** : Menampilkan semua data baik ketika ada yang cocok antara kedua tabel ataupun tidak

# %% [markdown]
# **ILUSTRASI**

# %% [markdown]
# ![join statement2.PNG](data:image/png;base64,...)

# %% [markdown]
# ##LEFT JOIN

# %% [markdown]
# ![Left join.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question
#
# Kamu di minta bos buat tarik customer_id, customer_name, dan list transaksi order_detail_id dari semua customer_id >= 29400
#
# **`Siapa saja customer BeeCycle diatas, beserta list transaksi nya (baik ada atau tidak) ???`**
#
# * Tarik customer_id, customer_name, dan order_detail_id pada tabel **dim_customer** dan **fact_sales**
# * untuk menggabungkan ke-2 table, JOIN menggunakan LEFT JOIN pada customer_id
# * Filter hanya customer_id >= 29400
# * Urutkan dari customer_id terkecil

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %%
# all customer_id >= 29400 in dibimbing.dim_customer
# tanpa alias

# %%bigquery --project sonic-utility-323206 

select dim_customer.customer_id, customer_name, order_detail_id
from dibimbing-386613.dibimbing.dim_customer left join dibimbing-386613.dibimbing.fact_sales
     on dim_customer.customer_id = fact_sales.customer_id
where dim_customer.customer_id >= 29400
order by dim_customer.customer_id asc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     customer_id      customer_name order_detail_id
# 0         29476  Elizabeth Bradley       SO45199-1
# 1         29466      Lance Jimenez       SO44918-1
# 2         29474         Jaime Raje       SO44949-1
# 3         29467       Monica Mehta       SO44831-1
# 4         99998    Diana Saraswati            None
# 5         99997         Siska Budi            None
# 6         99999  Aisyah Soebandono            None
# 7         29410        Lucas Price       SO44723-1
# 8         29481          Ivan Suri       SO45427-1
# 9         29448       Lindsey Yuan       SO44571-1
# 10        29449         Laura Chen       SO44646-1
# 11        29475         Jared Ward       SO45024-1

# %%
#menggunakan alias
# %%bigquery --project sonic-utility-323206 

select dc.customer_id, customer_name, order_detail_id
from dibimbing-386613.dibimbing.dim_customer as dc 
     left join dibimbing-386613.dibimbing.fact_sales as fs
     on dc.customer_id = fs.customer_id
where dc.customer_id >= 29400
order by dc.customer_id asc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     customer_id      customer_name order_detail_id
# 0         29476  Elizabeth Bradley       SO45199-1
# 1         29466      Lance Jimenez       SO44918-1
# 2         29474         Jaime Raje       SO44949-1
# 3         29467       Monica Mehta       SO44831-1
# 4         99998    Diana Saraswati            None
# 5         99997         Siska Budi            None
# 6         99999  Aisyah Soebandono            None
# 7         29410        Lucas Price       SO44723-1
# 8         29481          Ivan Suri       SO45427-1
# 9         29448       Lindsey Yuan       SO44571-1
# 10        29449         Laura Chen       SO44646-1
# 11        29475         Jared Ward       SO45024-1

# %%
#menggunakan using statement

# %%bigquery --project sonic-utility-323206 

select customer_id, customer_name, order_detail_id
from dibimbing-386613.dibimbing.dim_customer as dc 
     left join dibimbing-386613.dibimbing.fact_sales as fs
     using(customer_id)
where customer_id >= 29400
order by customer_id asc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     customer_id      customer_name order_detail_id
# 0         29476  Elizabeth Bradley       SO45199-1
# 1         29466      Lance Jimenez       SO44918-1
# 2         29474         Jaime Raje       SO44949-1
# 3         29467       Monica Mehta       SO44831-1
# 4         99998    Diana Saraswati            None
# 5         99997         Siska Budi            None
# 6         99999  Aisyah Soebandono            None
# 7         29410        Lucas Price       SO44723-1
# 8         29481          Ivan Suri       SO45427-1
# 9         29448       Lindsey Yuan       SO44571-1
# 10        29449         Laura Chen       SO44646-1
# 11        29475         Jared Ward       SO45024-1

# %% [markdown]
# ## RIGHT JOIN

# %% [markdown]
# ![right join.PNG](data:image/png;base64,...)

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question (same)
#
# Kamu di minta bos buat tarik customer_id, customer_name, dan list transaksi order_detail_id (TOP 5 Tertinggi)
#
# **`Siapa saja customer BeeCycle diatas, beserta list transaksi nya (baik ada atau tidak) ???`**
#
# * Tarik customer_id, customer_name, dan order_detail_id pada tabel **dim_customer** dan **fact_sales**
# * untuk menggabungkan ke-2 table, JOIN menggunakan RIGH JOIN pada customer_id
# * Urutkan dari order_detail_id terbesar (DESC)
# * limit 5

# %%
# %%bigquery --project sonic-utility-323206
#
#
# select fs.customer_id, customer_name, order_detail_id
# from dibimbing-386613.dibimbing.dim_customer as dc
# right join dibimbing-386613.dibimbing.fact_sales as fs
# on dc.customer_id = fs.customer_id
# order by order_detail_id desc
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id    customer_name order_detail_id
# 0         <NA>             None        SO9999-1
# 1        11947      Jenny Zheng       SO74093-1
# 2        12263  Emmanuel Garcia       SO74092-4
# 3        12263  Emmanuel Garcia       SO74092-3
# 4        12263  Emmanuel Garcia       SO74092-2

# %% [markdown]
# ##INNER JOIN

# %% [markdown]
# ![inner joinn.PNG](data:image/png;base64,...)

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question (same)
#
# **Kamu di minta bos buat tarik customer_id, customer_name, dan list transaksi order_detail_id dari semua customer_id >= 29400**
#
# **`Siapa saja customer BeeCycle diatas, beserta list transaksi nya (INNER JOIN) ???`**
#
# * Tarik customer_id, customer_name, dan order_detail_id pada tabel **dim_customer** dan **fact_sales**
# * untuk menggabungkan ke-2 table, JOIN menggunakan INNER JOIN pada customer_id
# * Filter hanya customer_id >= 29400
# * Urutkan dari customer_id terkecil

# %%
# %%bigquery --project sonic-utility-323206
#
# select dc.customer_id, customer_name, order_detail_id
# from dibimbing-386613.dibimbing.dim_customer as dc
# inner join
# dibimbing-386613.dibimbing.fact_sales as fs
# on dc.customer_id = fs.customer_id
# where dc.customer_id >= 29400
# order by dc.customer_id asc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id      customer_name order_detail_id
# 0        29410        Lucas Price       SO44723-1
# 1        29448       Lindsey Yuan       SO44571-1
# 2        29449         Laura Chen       SO44646-1
# 3        29466      Lance Jimenez       SO44918-1
# 4        29467       Monica Mehta       SO44831-1
# 5        29474         Jaime Raje       SO44949-1
# 6        29475         Jared Ward       SO45024-1
# 7        29476  Elizabeth Bradley       SO45199-1
# 8        29481          Ivan Suri       SO45427-1

# %% [markdown]
# ## FULL JOIN

# %% [markdown]
# ![full join.PNG](data:image/png;base64,...)

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question (same)
#
# Kamu di minta bos buat tarik customer_id, customer_name, dan list transaksi order_detail_id dari semua customer_id -> bahkan dari customer yg tidak terdaftar di dibimbing.dim_customer
#
# **`Siapa saja customer BeeCycle diatas, beserta list transaksi nya (baik ada atau tidak) ???`**
#
# * Tarik customer_id, customer_name, dan order_detail_id pada tabel **dim_customer** dan **fact_sales**
# * untuk menggabungkan ke-2 table, JOIN menggunakan FULL JOIN pada customer_id
# * Urutkan dari customer_id terbesar

# %%
# %%bigquery --project sonic-utility-323206
#
# select dc.customer_id, customer_name, order_detail_id
# from dibimbing-386613.dibimbing.dim_customer dc
# full join
# dibimbing-386613.dibimbing.fact_sales fs
# on dc.customer_id = fs.customer_id
# order by customer_id desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       customer_id      customer_name order_detail_id
# 0           99999  Aisyah Soebandono            None
# 1           99998    Diana Saraswati            None
# 2           99997         Siska Budi            None
# 3           29481          Ivan Suri       SO45427-1
# 4           29476  Elizabeth Bradley       SO45199-1
# ...           ...                ...             ...
# 5952        11000           Jon Yang       SO51522-1
# 5953        11000           Jon Yang       SO57418-4
# 5954        11000           Jon Yang       SO51522-2
# 5955        11000           Jon Yang       SO57418-5
# 5956         <NA>               None        SO9999-1
#
# [5957 rows x 3 columns]

# %% [markdown]
# ## Multiple JOIN

# %% [markdown]
# ![dim product x fact sales x dim customer.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question
#
# **`Berapa jumlah pembelian tiap customer dan product??? -> hanya tampilkan untuk customer yg terdaftar di database`**
#
# * Tarik product name, customer name dari **dim_customer** dan **dim_product** dan jumlah pembelian dari **fact sales**
# * untuk menggabungkan ke-2 table, JOIN menggunakan LEFT JOIN dan INNER JOIN
# * Urutkan dari jumlah pembelian terbesar
# * limit 10

# %%
# %%bigquery --project sonic-utility-323206
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#               product_name      customer_name  totalsales
# 0  Touring-1000 Yellow, 50     Francisco Sara  66753960.0
# 1  Touring-1000 Yellow, 46       Nichole Nara  66753960.0
# 2  Touring-1000 Yellow, 46  Kaitlyn Henderson  66753960.0
# 3  Mountain-200 Silver, 38     Gary Gutierrez  61479734.4
# 4  Mountain-200 Silver, 46            Alan He  61479734.4
# 5  Mountain-200 Silver, 42    Logan Hernandez  61479734.4
# 6  Mountain-200 Silver, 46      Calvin Chande  61479734.4
# 7  Mountain-200 Silver, 42      Xavier Bailey  61479734.4
# 8  Mountain-200 Silver, 38   Christine Chande  61479734.4
# 9  Mountain-200 Silver, 42      Wendy Alvarez  61479734.4

# %%
# Sub Query di join 

# %%bigquery --project sonic-utility-323206
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#               product_name      customer_name  totalsales
# 0  Mountain-200 Silver, 46            Alan He  61479734.4
# 1         Road-150 Red, 44    Arianna Simmons  50095780.0
# 2         Road-150 Red, 62        Sophia Hall  50095780.0
# 3         Road-150 Red, 48        Olivia Reed  50095780.0
# 4         Road-150 Red, 62       Paige Howard  50095780.0
# 5         Road-150 Red, 62       Marshall Lal  50095780.0
# 6         Road-150 Red, 48    Jennifer Barnes  50095780.0
# 7         Road-150 Red, 48  Alexandra Stewart  50095780.0
# 8         Road-150 Red, 44       Lucas Butler  50095780.0
# 9         Road-150 Red, 56      Justin Bryant  50095780.0

# %% [markdown]
# #UNION

# %% [markdown]
# The UNION operator combines result sets of two or more SELECT statements into a single result set.
#
# The following illustrates the syntax of the UNION operator that combines result sets from two queries:

# %% [markdown]
# ![union.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question
#
# **`Gabungkan 2 table dibimbing.dim_product menjadi 1 tabel memanjang (hanya untuk category Bikes dan product id < 320) `**

# %% [markdown]
# * tarik kolom product_id, product_name dari dibimbing.dim_product
# * filter hanya category = 'Bikes'
# * filter hanya product_id < 320
# * lakukan UNION DISTINCT / UNION ALL menggunakan tabel yg sama
# * Temukan perbedaannya

# %%
#UNION ALL 
# %%bigquery --project sonic-utility-323206 

select product_id, product_name 
from dibimbing-386613.dibimbing.dim_product
where category = 'Bikes'
and product_id < 320 

union all

select product_id, product_name 
from dibimbing-386613.dibimbing.dim_product
where category = 'Bikes'
and product_id < 320
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     product_id      product_name
# 0          317  Road-450 Red, 44
# 1          318  Road-450 Red, 48
# 2          319  Road-450 Red, 52
# 3          315  Road-450 Red, 58
# 4          316  Road-450 Red, 60
# 5          311  Road-150 Red, 44
# 6          312  Road-150 Red, 48
# 7          313  Road-150 Red, 52
# 8          314  Road-150 Red, 56
# 9          310  Road-150 Red, 62
# 10         317  Road-450 Red, 44
# 11         318  Road-450 Red, 48
# 12         319  Road-450 Red, 52
# 13         315  Road-450 Red, 58
# 14         316  Road-450 Red, 60
# 15         311  Road-150 Red, 44
# 16         312  Road-150 Red, 48
# 17         313  Road-150 Red, 52
# 18         314  Road-150 Red, 56
# 19         310  Road-150 Red, 62

# %%
#UNION DISTINCT 
# %%bigquery --project sonic-utility-323206 

select product_id, product_name 
from dibimbing-386613.dibimbing.dim_product
where category = 'Bikes'
and product_id < 320 

union distinct

select product_id, product_name 
from dibimbing-386613.dibimbing.dim_product
where category = 'Bikes'
and product_id < 320
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    product_id      product_name
# 0         317  Road-450 Red, 44
# 1         318  Road-450 Red, 48
# 2         319  Road-450 Red, 52
# 3         315  Road-450 Red, 58
# 4         316  Road-450 Red, 60
# 5         311  Road-150 Red, 44
# 6         312  Road-150 Red, 48
# 7         313  Road-150 Red, 52
# 8         314  Road-150 Red, 56
# 9         310  Road-150 Red, 62

# %%
# %%bigquery --project sonic-utility-323206
#
# select *
# from table_2018
#
# union all
#
# select *
# from table_2017

# %% [markdown]
# # DATE FUNCTION

# %% [markdown]
# ## Extract

# %% [markdown]
# Fungsi PostgreSQL EXTRACT mengambil partisi tanggal seperti tahun, bulan, dan hari dari nilai tanggal/waktu tertentu.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Extract Field Date.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
#
# select distinct extract(year from order_date)
# from dibimbing-386613.dibimbing.fact_sales
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     f0_
# 0  2019
# 1  2018
# 2  2016
# 3  2017

# %%
# %%bigquery --project sonic-utility-323206

# %% [markdown]
# ⭐ Question
#
# **`Berapa jumlah order tiap tahun dan tiap bulan dari BeeCycle? `**

# %% [markdown]
# * Query **Year** dan **Month** dari column **order_date** pada tabel **fact_sales** menggunakan (EXTRACT)
# * Hitung jumlah order dengan COUNT(DISTINCT order_detail_id)
# * urutkan berdasarkan **Year** dan **Month** nya

# %% [markdown]
# ![fact_sales.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# select extract(year from order_date) years,
#         extract(month from order_date) months,
#         count(distinct order_detail_id) as jumlah_pembelian
# from dibimbing-386613.dibimbing.fact_sales
# group by 1,2
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     years  months  jumlah_pembelian
# 0    2019       2               705
# 1    2018      11               514
# 2    2018       7               471
# 3    2018       8               505
# 4    2018       9               559
# 5    2018      10               508
# 6    2018      12               514
# 7    2019       1               503
# 8    2016       7                50
# 9    2016       8                46
# 10   2016       9                39
# 11   2016      11                69
# 12   2016      12                80
# 13   2017       1                59
# 14   2017       2                66
# 15   2017       3                87
# 16   2019       6               149
# 17   2016      10                55
# 18   2017       7                64
# 19   2019       5               206
# 20   2017      10                47
# 21   2017       4                36
# 22   2017       6                30
# 23   2017       9                42
# 24   2017      11                18
# 25   2017      12                23
# 26   2017       8                58
# 27   2019       3               163
# 28   2019       4               226
# 29   2017       5                31
# 30   2018       5                11
# 31   2018       6                11
# 32   2018       4                 6
# 33   2018       3                 3

# %%
# %%bigquery --project sonic-utility-323206
#
# select date_trunc(order_date, month) months,
#         count(distinct order_detail_id) as jumlah_pembelian
# from dibimbing-386613.dibimbing.fact_sales
# group by 1
# order by 1
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         months  jumlah_pembelian
# 0   2016-07-01                50
# 1   2016-08-01                46
# 2   2016-09-01                39
# 3   2016-10-01                55
# 4   2016-11-01                69
# 5   2016-12-01                80
# 6   2017-01-01                59
# 7   2017-02-01                66
# 8   2017-03-01                87
# 9   2017-04-01                36
# 10  2017-05-01                31
# 11  2017-06-01                30
# 12  2017-07-01                64
# 13  2017-08-01                58
# 14  2017-09-01                42
# 15  2017-10-01                47
# 16  2017-11-01                18
# 17  2017-12-01                23
# 18  2018-03-01                 3
# 19  2018-04-01                 6
# 20  2018-05-01                11
# 21  2018-06-01                11
# 22  2018-07-01               471
# 23  2018-08-01               505
# 24  2018-09-01               559
# 25  2018-10-01               508
# 26  2018-11-01               514
# 27  2018-12-01               514
# 28  2019-01-01               503
# 29  2019-02-01               705
# 30  2019-03-01               163
# 31  2019-04-01               226
# 32  2019-05-01               206
# 33  2019-06-01               149

# %%
# %%bigquery --project sonic-utility-323206
#
# select date_trunc('2023-02-28', year)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#           f0_
# 0  2023-01-01

# %%
# %%bigquery --project sonic-utility-323206
#
# select date_trunc('2023-02-28', month)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#           f0_
# 0  2023-02-01

# %% [markdown]
# ## Date Difference

# %% [markdown]
# Pada bagian ini akan digunakan fungsi DATE_DIFF() yang berfungsi untuk menghitung selisih antara 2 tanggal

# %% [markdown]
# ```
# SELECT DATE_DIFF( DATE1 , DATE2 , field_value)
# ```

# %% [markdown]
# Berapa selisih BULAN antara 1 Oktober 2020 dan 1 Agustus 2020 ?

# %%
# %%bigquery --project sonic-utility-323206
#
# select date_diff( date('2020-10-01'), date('2020-08-01'), month)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0    2

# %%
# %%bigquery --project sonic-utility-323206
# select current_date
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#           f0_
# 0  2023-05-20

# %% [markdown]
# Berapa selisih BULAN antara 1 Oktober 2021 dan 1 Agustus 2020 ?

# %%
# %%bigquery --project sonic-utility-323206
# select date_diff( date('2021-10-01'), date('2020-08-01'), month)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0   14

# %% [markdown]
# ⭐ Question
#
# Bos Marketing lagi sebar-sebar promo untuk customer Lansia. Karena sedang akan ada product baru sepeda kusus lansia.
#
# **`Siapa saja top 10 customer dengan umur paling senior (DESC) ?`**

# %% [markdown]
# * Query **customer_id, customer_name, birthdate, umur saat ini** pada tabel **dim_customer**
# * Urutkan dari umur paling senior (DESC)
# * Dan ambil TOP 10 (LIMIT 10)

# %% [markdown]
# ![fact_sales.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# select customer_id, customer_name,
# date_diff(current_date, birthdate, year) age
# from dibimbing-386613.dibimbing.dim_customer
# order by 3 desc
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id         customer_name  age
# 0        11555  Alexandria Henderson   77
# 1        11554        Sydney Simmons   77
# 2        11503             Dennis Wu   73
# 3        11504          Jordan Baker   72
# 4        11252     Nicholas Thompson   71
# 5        11255             Colin Lin   70
# 6        11253        José Hernandez   70
# 7        11257     Jacqueline Powell   70
# 8        11256     Katelyn Hernandez   70
# 9        11258           Xavier Hill   70

# %% [markdown]
# # NULL & NOT NULL

# %% [markdown]
# *   **IS NULL**	-> Return true if a value is NULL
# *   **IS NOT NULL**	-> Return true if a value is NOT NULL

# %%
# %%bigquery --project sonic-utility-323206

# %% [markdown]
# ##NULL

# %% [markdown]
# * Query all column pada tabel **fact_sales**
# * yg memiliki customer_id **NULL**

# %%
# %%bigquery --project sonic-utility-323206
#
# select *
# from dibimbing-386613.dibimbing.fact_sales
# where customer_id is not null
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   order_detail_id  order_date  product_id  customer_id  territory_id  \
# 0       SO63339-1  2019-02-01         353        15491             5
# 1       SO63339-3  2019-02-01         473        15491             5
# 2       SO63339-4  2019-02-01         477        15491             5
# 3       SO63339-2  2019-02-01         478        15491             5
# 4       SO57966-1  2018-11-15         480        11533             5
# 5       SO51184-3  2018-07-01         528        11263             1
# 6       SO51264-2  2018-07-06         528        11282             1
# 7       SO52054-2  2018-08-04         528        11207             1
# 8       SO52321-2  2018-08-09         528        11189             1
# 9       SO52322-3  2018-08-09         528        11216             1
#
#   sales_order_number  sales_order_line_number  quantity  unitprice_rupiah  \
# 0            SO63339                        1         1        32479860.0
# 1            SO63339                        3         1          889000.0
# 2            SO63339                        4         1           69860.0
# 3            SO63339                        2         1          139860.0
# 4            SO57966                        1         1           32060.0
# 5            SO51184                        3         1           69860.0
# 6            SO51264                        2         1           69860.0
# 7            SO52054                        2         1           69860.0
# 8            SO52321                        2         1           69860.0
# 9            SO52322                        3         1           69860.0
#
#    totalprice_rupiah  totalcost_rupiah  shippingprice_rupiah
# 0         32479860.0        17718673.0              811997.2
# 1           889000.0          332486.0               22225.0
# 2            69860.0           26128.2                1747.2
# 3           139860.0           52308.2                3497.2
# 4            32060.0           11991.0                 802.2
# 5            69860.0           26128.2                1747.2
# 6            69860.0           26128.2                1747.2
# 7            69860.0           26128.2                1747.2
# 8            69860.0           26128.2                1747.2
# 9            69860.0           26128.2                1747.2

# %% [markdown]
# ##NULL - Join Statement

# %% [markdown]
# Karena customer female yang berumur > 50 tahun udah pernah dapat promo tahun lalu, tahun ini bakal di exclude customer2 tersebut..
#
#
# Query customer_id beserta jumlah transaksi , namun exclude customer yang female dan berumur > 50 tahun

# %% [markdown]
# jumlah transaksi = count distinct order_detail_id

# %%
# %%bigquery --project sonic-utility-323206

# %% [markdown]
# #Rank

# %% [markdown]
# PostgreSQL menawarkan beberapa fungsi RANK / peringkat. Mari kita EXPLORE  ketiganya:
# * RANK(),
# * DENSE_RANK() and
# * ROW_NUMBER().
#
# Berikut format penggunaan sintaks ini :

# %% [markdown]
# ![rank13.PNG](data:image/png;base64,...)

# %% [markdown]
# * Fungsi  **PARTITION BY** akan membuat partisi dalam hasil kueri RANK() diterapkan.
# * Fungsi **ORDER BY** menetapkan urutan tampilan hasil kueri

# %% [markdown]
# Contoh posisi dari RANK / PARTITION / ORDER BY ini misalnya:
#
# **TOP 10 Buyer berdasarkan sales tertinggi untuk seluruh transaksi**
# * Tidak menggunakan partition
# * Menggunakan order by SALES DESC
#
# **TOP 10 Buyer berdasarkan sales tertinggi untuk tiap periode BULAN**
# * Menggunakan partition periode bulan
# * Menggunakan order by SALES DESC
#
# **TOP 10 Buyer berdasarkan sales tertinggi DAN quantity tertinggi untuk tiap periode BULAN dan tiap CITY**
# * Menggunakan partition periode bulan dan city
# * Menggunakan order by SALES DESC dan QTY DESC

# %% [markdown]
# ##Rank()

# %% [markdown]
# Fungsi RANK() digunakan untuk memberikan peringkat ke setiap hasil kueri berdasarkan partisi yang ditentukan. Peringkat pertama dalam setiap partisi adalah 1.
#
# Berikut ilustrasi sintaks fungsi RANK():

# %% [markdown]
# ![rank1.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question
#
# Reward bulan ini akan diberikan kepada customer yg memiliki peringkat paling tinggi berdasarkan banyaknya jumlah transaksi
#
# **`Siapa saja top 10 customer dengan pembelian terbanyak bulan ini?`**

# %% [markdown]
# * Query **customer_id, customer_name, dan jumlah transaksi** (count distinct order detail_id) pada tabel **dim_customer** dan **fact_sales** (hint : left join function)
# * Lalu tambahkan kolom rank, dimana mengambil rank dari **jumlah transaksi terbanyak (DESC)** ***(hint : Rank())***
# * ambil hanya TOP 10 (LIMIT 10)

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# select fs.customer_id,
#        customer_name,
#        count(distinct order_detail_id) as jumlah_order,
#        rank() over (order by count(distinct order_detail_id) desc) as rank_sales
# from dibimbing-386613.dibimbing.fact_sales fs
# left join dibimbing-386613.dibimbing.dim_customer dc on dc.customer_id = fs.customer_id
# group by 1,2
# order by 3 desc
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id     customer_name  totalsales  rank_type
# 0        11331  Samantha Jenkins          43          1
# 1        11287      Henry Garcia          41          2
# 2        11091      Dalton Perez          38          3
# 3        11277   Charles Jackson          38          3
# 4        11566        April Shan          35          5
# 5        11176     Mason Roberts          35          5
# 6        11200     Jason Griffin          34          7
# 7        11223  Hailey Patterson          34          7
# 8        11330     Ryan Thompson          34          7
# 9        11300   Fernando Barnes          33         10

# %% [markdown]
# Apakah kamu menemukan ada yg menarik pada hasilnya?

# %% [markdown]
# ##Dense_Rank()

# %% [markdown]
# Berbeda dari fungsi RANK(), fungsi DENSE_RANK() selalu mengembalikan nilai peringkat berurutan. Berikut sintaksnya:

# %% [markdown]
# ![dense_rank.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question
#
# Reward bulan ini akan diberikan kepada customer yg memiliki peringkat paling tinggi berdasarkan banyaknya jumlah transaksi
#
# **`Siapa saja top 10 customer dengan pembelian terbanyak bulan ini?`**

# %% [markdown]
# * Query **customer_id, customer_name, dan jumlah transaksi** (count distinct order detail_id) pada tabel **dim_customer** dan **fact_sales** (hint : left join function)
# * Lalu tambahkan kolom rank, dimana mengambil rank dari **jumlah transaksi terbanyak (DESC)** ***(hint : dense_rank())***
# * ambil hanya TOP 10 (LIMIT 10)

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
#
# select fs.customer_id,
#        customer_name,
#        count(distinct order_detail_id) as jumlah_order,
#        dense_rank() over (order by count(distinct order_detail_id) desc) as drank_sales
# from dibimbing-386613.dibimbing.fact_sales fs
# left join dibimbing-386613.dibimbing.dim_customer dc on dc.customer_id = fs.customer_id
# group by 1,2
# order by 3 desc
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id     customer_name  totalsales  denrank_type
# 0        11331  Samantha Jenkins          43             1
# 1        11287      Henry Garcia          41             2
# 2        11091      Dalton Perez          38             3
# 3        11277   Charles Jackson          38             3
# 4        11566        April Shan          35             4
# 5        11176     Mason Roberts          35             4
# 6        11223  Hailey Patterson          34             5
# 7        11200     Jason Griffin          34             5
# 8        11330     Ryan Thompson          34             5
# 9        11300   Fernando Barnes          33             6

# %% [markdown]
# ##Row_Number

# %% [markdown]
# Fungsi ROW_NUMBER() menetapkan bilangan \berurutan untuk setiap result data

# %% [markdown]
# ![rownumber.PNG](data:image/png;base64,...)

# %% [markdown]
# ⭐ Question
#
# Reward bulan ini akan diberikan kepada customer yg memiliki peringkat paling tinggi berdasarkan banyaknya jumlah transaksi
#
# **`Siapa saja top 10 customer dengan pembelian terbanyak bulan ini?`**

# %% [markdown]
# * Query **customer_id, customer_name, dan jumlah transaksi** (count distinct order detail_id) pada tabel **dim_customer** dan **fact_sales** (hint : left join function)
# * Lalu tambahkan kolom rank, dimana mengambil rank dari **jumlah transaksi terbanyak (DESC)** ***(hint : row_number())***
# * ambil hanya TOP 10 (LIMIT 10)

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# select fs.customer_id,
#        customer_name,
#        count(distinct order_detail_id) as jumlah_order,
#        row_number() over (order by count(distinct order_detail_id) desc) as rownum_sales
# from dibimbing-386613.dibimbing.fact_sales fs
# left join dibimbing-386613.dibimbing.dim_customer dc on dc.customer_id = fs.customer_id
# group by 1,2
# order by 3 desc
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id     customer_name  totalsales  denrank_type
# 0        11331  Samantha Jenkins          43             1
# 1        11287      Henry Garcia          41             2
# 2        11277   Charles Jackson          38             3
# 3        11091      Dalton Perez          38             4
# 4        11176     Mason Roberts          35             5
# 5        11566        April Shan          35             6
# 6        11200     Jason Griffin          34             9
# 7        11330     Ryan Thompson          34             7
# 8        11223  Hailey Patterson          34             8
# 9        11300   Fernando Barnes          33            10

# %% [markdown]
# Sekarang, untuk membandingkan semua jenis rank, kamu membuat 1 tabel baru dengan ke 3 kolom yg berbeda untuk perbandingan
#
# * Query **customer_id, customer_name, dan jumlah transaksi** (count distinct order detail_id) pada tabel **dim_customer** dan **fact_sales** (hint : left join function)
# * Lalu tambahkan kolom rank, dimana mengambil rank dari **jumlah transaksi terbanyak (DESC)** ***(hint : Rank(), dense_rank(), row_number() )***
# * ambil hanya TOP 10 (LIMIT 10)

# %%
# %%bigquery --project sonic-utility-323206
# select fs.customer_id,
#        customer_name,
#        count(distinct order_detail_id) as jumlah_order,
#        rank() over (order by count(distinct order_detail_id) desc) as rank_sales,
#        dense_rank() over (order by count(distinct order_detail_id) desc) as drank_sales,
#        row_number() over (order by count(distinct order_detail_id) desc) as rownum_sales
# from dibimbing-386613.dibimbing.fact_sales fs
# left join dibimbing-386613.dibimbing.dim_customer dc on dc.customer_id = fs.customer_id
# group by 1,2
# order by 3 desc
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    customer_id     customer_name  totalsales  rank_type  denrank_type  \
# 0        11331  Samantha Jenkins          43          1             1
# 1        11287      Henry Garcia          41          2             2
# 2        11091      Dalton Perez          38          3             3
# 3        11277   Charles Jackson          38          3             3
# 4        11566        April Shan          35          5             4
# 5        11176     Mason Roberts          35          5             4
# 6        11200     Jason Griffin          34          7             5
# 7        11330     Ryan Thompson          34          7             5
# 8        11223  Hailey Patterson          34          7             5
# 9        11300   Fernando Barnes          33         10             6
#
#    rowrank_type
# 0             1
# 1             2
# 2             4
# 3             3
# 4             6
# 5             5
# 6             9
# 7             7
# 8             8
# 9            10

# %% [markdown]
# ##Partition By

# %% [markdown]
# Reward ternyata hanya akan diberikan untuk TOP 3 Customer berdasarkan jumlah transaksi terbanyak TIAP TAHUN ni.. jadi masing-masing tahun dari tahun 2016 - 2019 akan memiliki masing-masing 3 pemenang utama. Siapa TOP 3 Pemenang tiap tahun?

# %% [markdown]
# ⭐ Question
#
# Reward ternyata hanya akan diberikan untuk TOP 3 Customer berdasarkan jumlah transaksi terbanyak TIAP TAHUN ni..
#
# jadi masing-masing tahun (2016 - 2019) akan memiliki masing-masing 3 pemenang utama.
#
# **`Siapa saja TOP 3 Pemenang tiap tahun? (2016-2019) `**

# %% [markdown]
# * Query **Years dari order_date, customer_id, customer_name, dan jumlah transaksi**  dari tabel **dim_customer** dan **fact_sales** (use left join)
# * Lalu tambahan kolom Rank berdasarkan **jumlah transaksi terbanyak (DESC)** (use rank / denserank / or rownumber)
# * dan **partisi** Rank berdasarkan Years pada order_date
#
#
# *jumlah transaksi = count distinct order_detail_id

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
# --  TOP 3 Pemenang tiap tahun? (2016-2019)
# with
# ranking as
# (select extract(year from order_date) years,
#        fs.customer_id,
#        customer_name,
#        count(distinct order_detail_id) sales,
# from dibimbing-386613.dibimbing.fact_sales fs
# left join dibimbing-386613.dibimbing.dim_customer dc on fs.customer_id = dc.customer_id
# where extract(year from order_date)  between 2016 and 2019
# group by 1,2,3),
#
# ranking_fix as
# (select *, row_number() over (partition by years order by sales desc) as rownum
# from ranking)
#
# select *
# from ranking_fix
# where rownum <= 3
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     years  customer_id     customer_name  totalsales  rownum
# 0    2016        27605   Miguel Martinez           1       1
# 1    2016        28041    Rebecca Wright           1       2
# 2    2016        28148          Jon Zhao           1       3
# 3    2018        11331  Samantha Jenkins          34       1
# 4    2018        11287      Henry Garcia          32       2
# 5    2018        11176     Mason Roberts          31       3
# 6    2017        29140      Richard Ward           1       1
# 7    2017        29146     Ian Henderson           1       2
# 8    2017        29169   Victoria Bailey           1       3
# 9    2019        11300   Fernando Barnes          14       1
# 10   2019        11185  Ashley Henderson          14       2
# 11   2019        11223  Hailey Patterson          13       3

# %% [markdown]
# #Others

# %% [markdown]
# ##Percentile Cont()

# %% [markdown]
# When you use percentile_cont window function, PostgreSQL will interpolate the median value as the average of 2 middle values (210, 215), in case there are 2 middle values. That is why it returns 212.5

# %% [markdown]
# **`SELECT PERCENTILE_CONT(0.5) WITHIN GROUP(ORDER BY sale) FROM sales;`**

# %% [markdown]
# * In the above query, we use percentile_cont window function that allows you to define what percentile (e.g 0.5 that is 50th percentile) you want to calculate
# * Then we also use WITHIN GROUP clause to calculate percentile within the group of sale values.
# * We also use ORDER BY clause to sort the sale values before we calculate percentile in PostgreSQL.

# %% [markdown]
# Kamu diminta untuk cari median total transaksi ni.. biar tim operational dapat bayangan kira2 per transaksi biasanya customer spend berapa rupiah ya

# %% [markdown]
# * Query percentile cont (0.5) untuk mengetahui median pada column totalprice_rupiah pada tabel **fact_sales**

# %% [markdown]
# ![fact_sales.PNG](data:image/png;base64,...)

# %%
# %%bigquery --project sonic-utility-323206
#
#   select distinct percentile_cont(totalprice_rupiah, 0.5) over ()
#  FROM `dibimbing-386613.dibimbing.fact_sales`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         f0_
# 0  489860.0

# %% [markdown]
# ##Percentile Cont() Partition By

# %% [markdown]
# Jika ingin melihat median dari partition tertentu, untuk beberapa DBMS menggunakan partition by seperti pada Rank / denserank / rownumber. Namun pada postgre, dapat menggunakan group by seperti pada formula aggregation

# %%
# %%bigquery --project sonic-utility-323206
#  select distinct territory_id , percentile_cont(totalprice_rupiah, 0.5) over (partition by territory_id)
#  FROM `dibimbing-386613.dibimbing.fact_sales`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    territory_id       f0_
# 0             6  349860.0
# 1             5  139860.0
# 2             7  489860.0
# 3             4  490000.0
# 4             1  490000.0
# 5             9  755860.0
# 6            10  489860.0
# 7             8  490000.0

# %% [markdown]
# ## Pembulatan - Round

# %%
# %%bigquery --project sonic-utility-323206
#
# select round(12.35555,2)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      f0_
# 0  12.36

# %% [markdown]
# ##Pembulatan - Floor

# %%
# %%bigquery --project sonic-utility-323206
#
# select floor(12.7)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     f0_
# 0  12.0

# %% [markdown]
# ##Pembulatan - Ceiling

# %%
# %%bigquery --project sonic-utility-323206
#
# select ceiling(12.1555)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     f0_
# 0  13.0

# %% [markdown]
# ## Concat

# %%
# %%bigquery --project sonic-utility-323206
# select concat(customer_name,' lahir pada tanggal ', birthdate)
# from dibimbing-386613.dibimbing.dim_customer
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                f0_
# 0        Darren Gill lahir pada tanggal 1973-05-14
# 1      Crystal Liang lahir pada tanggal 1988-09-06
# 2        Kaylee Hill lahir pada tanggal 1984-03-03
# 3  Antonio Patterson lahir pada tanggal 1975-06-13
# 4    Kristina Kapoor lahir pada tanggal 1980-04-07
# 5         Cedric Liu lahir pada tanggal 1994-11-05
# 6     Jennifer Green lahir pada tanggal 2000-05-19
# 7   Gerald Rodriguez lahir pada tanggal 1982-04-02
# 8        Curtis Yang lahir pada tanggal 1982-06-06
# 9         Carly Goel lahir pada tanggal 1989-11-13

# %% [markdown]
# #Assignment 1

# %% [markdown]
# ## Question 1

# %% [markdown]
# Create table bernama dim_customer_(nick name kamu) dengan column name (string) , birthdate (date) , and gender (string)

# %% [markdown]
# Select * pada dim_customer_(nick name kamu)

# %% [markdown]
# Screen capture

# %% [markdown]
# ## Question 2

# %% [markdown]
# Alter tabel dim_customer_(nick name kamu) dan ubah namanya menjadi dim_customer_(nick name kamu)_(movie yang kamu suka)

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create table bernama dim_customer_(last name kamu) dan isi datanya dengan data pada dim customer yang memiliki gender female

# %% [markdown]
# ## Question 4

# %% [markdown]
# Create sebuah table yang berasal dari google spreadsheet. Nama table, isi table, tujuan table dsb bebas sekreatif mungkin. Sertakan screenshot saat 'create table' , dan SELECT * FROM Table setelah table jadi

# %% [markdown]
# **Screenshot please put here**

# %% [markdown]
# #Assignment 2

# %% [markdown]
# ## Question 1

# %% [markdown]
# Untuk mengetahui target customer BeeCycle.
# Kamu melakukan query untuk melihat distribusi customer berdasarkan gender dan umur.

# %% [markdown]
# Dimana untuk category umur, kamu membagi umur customer kedalam  (Hint : CASE WHEN)
# * umur customer <= 20 tahun maka **'Group <=20'**
# * umur customer antara 21 dan 40 tahun maka **'Group 21 - 40'**
# * umur customer antara 41 dan 60 tahun maka **'Group 41 - 60'**
# * umur customer lebih dari 60 tahun maka **'Group >60'**

# %% [markdown]
# Dengan grouping_age yg sudah didefine, selanjutnya jawab pertanyaan berikut

# %% [markdown]
# **Grouping age apa dan gender apa yg memiliki transaksi paling tinggi di BeeCycle?**

# %% [markdown]
# ![fact sales x dim customer.PNG](data:image/png;base64,...)

# %% [markdown]
# Answer

# %%
#Tulis Query disini

# %%bigquery --project sonic-utility-323206

# %% [markdown]
# ## Question 2

# %% [markdown]
# Karena bulan Oktober depan akan ada campaign.
# Kamu punya ide untuk menghilight warna product tertentu yg menjadi kegemaran customer. Kamu selanjutnya melakukan query untuk menjawab pertanyaan berikut :

# %% [markdown]
# **Warna apa di tiap tahun yg menjadi warna paling populer dibeli oleh customer?**

# %% [markdown]
# ![dim product x fact sales.PNG](data:image/png;base64,...)

# %%
#Tulis Query disini

# %%bigquery --project sonic-utility-323206

# %% [markdown]
# ## Question 3

# %% [markdown]
# ![dim product x fact sales.PNG](data:image/png;base64,...)

# %% [markdown]
# Karena campaign bulan Oktober tsb hanya terbatas untuk tiap2 toko cabang.
# kamu punya ide, bagaimana hanya mengambil TOP 10 product_id dari masing2 toko cabang. sehingga kamu melakukan query untuk menjawab pertanyaan berikut :

# %% [markdown]
# **TOP 10 product name apa saja yg paling populer dari masing-masing territory>**

# %% [markdown]
# Answer

# %%
#Tulis Query disini

# %%bigquery --project sonic-utility-323206

# %% [markdown]
# ## Question 4

# %% [markdown]
# Karena sudah lulus probation nih.. kamu diminta untuk membuat sendiri analysis untuk si Bos. Beberapa step yg perlu dilakukan adalah :
# 1. Membuat objective analysis (contoh : Karena next campaign mau dibuat maksimal , kita akan menghilight top2 product)
# 2. Membuat business question (contoh : Apa saja product yg paling populer dari segi jumlah transaksi?)
# 3. Build the Query untuk menjawab pertanyaan pada poin no 2
# 4. Tulis Actionable knowledge atau next action setelah mendapat jawaban dari poin 3 (contoh : product abc yg paling tinggi sehingga kita akan fokus untuk promosi product tersebut)

# %% [markdown]
# Answer

# %% [markdown]
# Objective :

# %% [markdown]
# Business Question :

# %%
#Tulis Query disini

# %%bigquery --project sonic-utility-323206

# %% [markdown]
# Actionable knowledge :
